# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(3.798202575538852, -157.76060847821464), (-77.99130595582574, 114.77577522919131), (84.28778893964216, -156.57763837008926), (-67.58388769739807, -158.72886576947033), (38.663638560093574, -38.48905263734838), (11.874602322911272, -77.4419024374047), (15.19229142012783, -140.51007346092888), (88.5044346671784, -129.76862033672188), (-59.151522393384866, -172.25734789467438), (-45.464710895840156, 168.43316654512222), (-31.059140607265064, 64.24150467919182), (-85.7166540600242, -49.53851421794309), (-57.78013486639802, 51.250522386135174), (-72.73498727320712, 166.5923988526224), (-86.35680176805582, 15.176759347744195), (-58.524937133383084, 175.66085408450465), (54.2219549779727, -58.66970570873379), (-18.875349359389347, -46.95102613573829), (54.468195770725686, -100.46779623767138), (71.11850634896169, 20.992019169683402), (-27.203442008264787, 27.14823659221389), (-36.294891444075, -153.6460205486142), (-25.186217280381342, 97.92353128438134), (49.3001263127737, 163.9637438746168), (84.33353482022568, -30.549501033458228), (-80.2663480066437, -61.0774098229264), (40.15453987573801, 82.95934391317536), (-23.34919742749858, 109.30677432724605), (-55.788126665107875, -156.93788545134996), (84.26450209293301, -127.5657627967046), (67.00374717908554, 103.24569121824862), (-30.6247414136717, -71.01371149155155), (-20.141192402544803, 142.56590398748597), (47.212606496311565, -27.23422242997333), (-18.375014285588804, 149.4469491512317), (77.193839435585, 159.70512810902272), (38.73296083760232, -88.98725784073208), (57.735269513813336, 41.90829484168674), (86.74376136002564, -85.99069386139361), (64.26815396620694, -120.86489556498401), (-46.13594037265131, 13.199691953774135), (71.51568052370754, -161.2874152012815), (47.009826670073835, -110.33076973026466), (-67.19192341906802, 37.181014227142725), (-34.63417347349778, 163.97451351686954), (-81.05760369969674, -79.95815507115695), (0.6183267994732375, -100.5357977088174), (-68.16291255548813, -93.19267167891381), (-13.814865690200591, 170.9844759463478), (56.55644316853568, -31.321030603294446), (-31.761803565794025, -38.05741902546336), (-33.204172709746224, -18.316160515914817), (54.194967861422555, 35.73179371572738), (-78.55254225450152, -82.45573847908362), (48.82338113154077, 139.7720008329781), (62.89770558881469, -141.69668024238035), (13.320615595024108, 37.85005472235801), (12.92155269028757, -15.67100452728394), (-43.634561791660715, 24.043030374946483), (32.69308687598527, 85.53405774416643), (-53.99433829036629, -100.29488593525089), (-53.951464488760564, 102.3166313978025), (-23.459574453581567, -22.104823155316126), (-48.369448754180425, -51.683613507069936), (72.35068013577475, -121.26370239374458), (-7.393029233305086, -93.44165385152381), (-20.615943542455014, -148.08609763260543), (-26.005206447210824, -124.63144266885638), (-12.7818099103784, 8.10920907068845), (-78.56905661053516, 15.746939151637804), (70.5633671829101, -68.74892713388529), (79.53453514769222, 133.82434339445774), (18.494967042087097, 46.95388935091762), (-1.7972857906230644, -111.67307504818041), (-21.51839277810521, 121.77746829461381), (-20.204039897763096, 156.392394796679), (5.645383407400473, -145.89101294114397), (-89.047112227026, 86.28103416949148), (8.581408468795345, -54.50146377951293), (76.76669559766512, -170.54979099765484), (-26.881687567775018, -29.015747619759026), (-54.490963905991784, 9.212001647923728), (-48.89766024178202, 55.80087884343041), (-74.77132953175473, -20.982217370138443), (29.50240681956508, 124.7192577791053), (5.442960040097233, -51.97844915512928), (88.55310086815678, 175.95542730687833), (42.85646864137661, -178.36770560294892), (28.703622701943715, 163.12041329136576), (28.88194662704329, 91.41313418524595), (89.56755276066508, 31.985858123169862), (-2.7589754172374086, 111.4499485784205), (-77.28094523606147, 38.61362106546534), (-10.42307759824729, -104.29030035732075), (-48.27017913209752, -31.415288528430267), (6.328271002220021, -150.5834197 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 786

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6e49f21ff364fdff499a4f066ae649aa'

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | cartagena
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | winton
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | saint-augustin
# Processing Record 17 of Set 1 | patrocinio
# Processing Record 18 of Set 1 | the pas
# Processing Record 19 of Set 1 | skjervoy
# Processing Record 20 of Set 1 | viljoenskroon
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 1 | tura
# Processing Record 26 of Set 1 | monte patria
# Processing Record 27 of Set 1 | mount isa
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | bowen
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | centralia
# Processing Record 32 of Set 1 | sudislavl
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | fort nelson
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | lewistown
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | ahipara
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | sola
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | kozelsk
# Processing Record 46 of Set 1 | mayskiy
# Processing Record 47 of Set 1 | haines junction
# Processing Record 48 of Set 1 | dabat
# Processing Record 49 of Set 1 | sedhiou
# Processing Record 50 of Set 1 | plettenberg bay
# Processing Record 1 of Set 2 | pokhara
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | teahupoo
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | namibe
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | najran
# Processing Record 13 of Set 2 | port hedland
# Processing Record 14 of Set 2 | bundaberg
# Processing Record 15 of Set 2 | marienburg
# Processing Record 16 of Set 2 | lavrentiya
# Processing Record 17 of Set 2 | vila velha
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | shenjiamen
# Processing Record 20 of Set 2 | cayenne
# Processing Record 21 of Set 2 | leningradskiy
# Processing Record 22 of Set 2 | provideniya
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | lasa
# Processing Record 25 of Set 2 | berlevag
# Processing Record 26 of Set 2 | pangkalanbuun
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | hermon
# Processing Record 29 of Set 2 | ocolis
# City not found. Skipping...
# Processing Record 30 of Set 2 | aykhal
# Processing Record 31 of Set 2 | riese
# City not found. Skipping...
# Processing Record 32 of Set 2 | upala
# Processing Record 33 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | inhambane
# Processing Record 36 of Set 2 | channel-port aux basques
# Processing Record 37 of Set 2 | harper
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | tadine
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | rawson
# Processing Record 42 of Set 2 | zykovo
# Processing Record 43 of Set 2 | port hardy
# Processing Record 44 of Set 2 | kjollefjord
# Processing Record 45 of Set 2 | sorata
# Processing Record 46 of Set 2 | payo
# Processing Record 47 of Set 2 | olafsvik
# Processing Record 48 of Set 2 | talcahuano
# Processing Record 49 of Set 2 | alofi
# Processing Record 50 of Set 2 | loughton
# Processing Record 1 of Set 3 | wewak
# Processing Record 2 of Set 3 | concordia
# Processing Record 3 of Set 3 | kudahuvadhoo
# Processing Record 4 of Set 3 | caravelas
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | belmonte
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | great falls
# Processing Record 9 of Set 3 | gillette
# Processing Record 10 of Set 3 | deputatskiy
# Processing Record 11 of Set 3 | durban
# Processing Record 12 of Set 3 | chulym
# Processing Record 13 of Set 3 | valdez
# Processing Record 14 of Set 3 | cape town
# Processing Record 15 of Set 3 | hakkari
# Processing Record 16 of Set 3 | araouane
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | jining
# Processing Record 24 of Set 3 | salalah
# Processing Record 25 of Set 3 | mahanje
# Processing Record 26 of Set 3 | portland
# Processing Record 27 of Set 3 | taoudenni
# Processing Record 28 of Set 3 | hobart
# Processing Record 29 of Set 3 | kurilsk
# Processing Record 30 of Set 3 | talakan
# Processing Record 31 of Set 3 | kaputa
# Processing Record 32 of Set 3 | zhuanghe
# Processing Record 33 of Set 3 | margate
# Processing Record 34 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 3 | ocos
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | takoradi
# Processing Record 41 of Set 3 | cockburn town
# Processing Record 42 of Set 3 | milkovo
# Processing Record 43 of Set 3 | yellowknife
# Processing Record 44 of Set 3 | bay city
# Processing Record 45 of Set 3 | isangel
# Processing Record 46 of Set 3 | chenzhou
# Processing Record 47 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 48 of Set 3 | zhezkazgan
# Processing Record 49 of Set 3 | hit
# Processing Record 50 of Set 3 | shirokiy
# Processing Record 1 of Set 4 | san cristobal
# Processing Record 2 of Set 4 | hofn
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | boda
# Processing Record 6 of Set 4 | karratha
# Processing Record 7 of Set 4 | ningan
# City not found. Skipping...
# Processing Record 8 of Set 4 | dikson
# Processing Record 9 of Set 4 | bairiki
# Processing Record 10 of Set 4 | thinadhoo
# Processing Record 11 of Set 4 | prainha
# Processing Record 12 of Set 4 | taltal
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | acapulco
# Processing Record 15 of Set 4 | bambous virieux
# Processing Record 16 of Set 4 | petushki
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | sovetskiy
# Processing Record 19 of Set 4 | kalmunai
# Processing Record 20 of Set 4 | hope
# Processing Record 21 of Set 4 | udachnyy
# Processing Record 22 of Set 4 | svetlyy
# Processing Record 23 of Set 4 | rota
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | payette
# Processing Record 26 of Set 4 | alappuzha
# Processing Record 27 of Set 4 | avarua
# Processing Record 28 of Set 4 | naze
# Processing Record 29 of Set 4 | vila franca do campo
# Processing Record 30 of Set 4 | steamboat springs
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | weatherford
# Processing Record 33 of Set 4 | mapiripan
# Processing Record 34 of Set 4 | valdivia
# Processing Record 35 of Set 4 | nishihara
# Processing Record 36 of Set 4 | narsipatnam
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | launceston
# Processing Record 39 of Set 4 | oxford
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | xichang
# Processing Record 42 of Set 4 | east london
# Processing Record 43 of Set 4 | vokhtoga
# Processing Record 44 of Set 4 | yerbogachen
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | buraydah
# Processing Record 47 of Set 4 | farias brito
# Processing Record 48 of Set 4 | kavaratti
# Processing Record 49 of Set 4 | dubai
# Processing Record 50 of Set 4 | honiara
# Processing Record 1 of Set 5 | batemans bay
# Processing Record 2 of Set 5 | nelson bay
# Processing Record 3 of Set 5 | san joaquin
# Processing Record 4 of Set 5 | santa engracia
# Processing Record 5 of Set 5 | shonguy
# Processing Record 6 of Set 5 | umm lajj
# Processing Record 7 of Set 5 | vestmannaeyjar
# Processing Record 8 of Set 5 | musiri
# Processing Record 9 of Set 5 | paita
# Processing Record 10 of Set 5 | salinopolis
# Processing Record 11 of Set 5 | charlestown
# Processing Record 12 of Set 5 | kieta
# Processing Record 13 of Set 5 | san andres
# Processing Record 14 of Set 5 | solnechnyy
# Processing Record 15 of Set 5 | kodiak
# Processing Record 16 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 5 | kikwit
# Processing Record 18 of Set 5 | kaeo
# Processing Record 19 of Set 5 | lakhipur
# Processing Record 20 of Set 5 | mandera
# Processing Record 21 of Set 5 | gat
# Processing Record 22 of Set 5 | bengkulu
# Processing Record 23 of Set 5 | mayumba
# Processing Record 24 of Set 5 | kununurra
# Processing Record 25 of Set 5 | nalgonda
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 5 | kiev
# Processing Record 29 of Set 5 | cootamundra
# Processing Record 30 of Set 5 | narsaq
# Processing Record 31 of Set 5 | rabo de peixe
# Processing Record 32 of Set 5 | kralendijk
# Processing Record 33 of Set 5 | ghatanji
# Processing Record 34 of Set 5 | santa cruz
# Processing Record 35 of Set 5 | college
# Processing Record 36 of Set 5 | hithadhoo
# Processing Record 37 of Set 5 | asfi
# Processing Record 38 of Set 5 | cabo san lucas
# Processing Record 39 of Set 5 | chokurdakh
# Processing Record 40 of Set 5 | anapskaya
# Processing Record 41 of Set 5 | westport
# Processing Record 42 of Set 5 | la ronge
# Processing Record 43 of Set 5 | iqaluit
# Processing Record 44 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 5 | pazaric
# Processing Record 47 of Set 5 | avera
# Processing Record 48 of Set 5 | olga
# Processing Record 49 of Set 5 | viseu
# Processing Record 50 of Set 5 | sao filipe
# Processing Record 1 of Set 6 | novyy urengoy
# Processing Record 2 of Set 6 | mitsamiouli
# Processing Record 3 of Set 6 | coihaique
# Processing Record 4 of Set 6 | geraldton
# Processing Record 5 of Set 6 | taksimo
# Processing Record 6 of Set 6 | papara
# Processing Record 7 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 6 | sitka
# Processing Record 9 of Set 6 | karoi
# Processing Record 10 of Set 6 | longyearbyen
# Processing Record 11 of Set 6 | forli
# Processing Record 12 of Set 6 | ierissos
# Processing Record 13 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 6 | komsomolskiy
# Processing Record 15 of Set 6 | guerrero negro
# Processing Record 16 of Set 6 | tautira
# Processing Record 17 of Set 6 | zangakatun
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | noumea
# Processing Record 20 of Set 6 | zhangjiakou
# Processing Record 21 of Set 6 | parkes
# Processing Record 22 of Set 6 | fuerte
# Processing Record 23 of Set 6 | tigre
# Processing Record 24 of Set 6 | muli
# Processing Record 25 of Set 6 | tangier
# Processing Record 26 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 28 of Set 6 | kapaa
# Processing Record 29 of Set 6 | alice springs
# Processing Record 30 of Set 6 | holovyne
# Processing Record 31 of Set 6 | bilibino
# Processing Record 32 of Set 6 | kyabe
# Processing Record 33 of Set 6 | san quintin
# Processing Record 34 of Set 6 | ilave
# Processing Record 35 of Set 6 | aljezur
# Processing Record 36 of Set 6 | vytegra
# Processing Record 37 of Set 6 | sao gabriel da cachoeira
# Processing Record 38 of Set 6 | yumen
# Processing Record 39 of Set 6 | lucapa
# Processing Record 40 of Set 6 | cooma
# Processing Record 41 of Set 6 | arrifes
# Processing Record 42 of Set 6 | parakan
# Processing Record 43 of Set 6 | uniao
# Processing Record 44 of Set 6 | lhokseumawe
# Processing Record 45 of Set 6 | road town
# Processing Record 46 of Set 6 | turukhansk
# Processing Record 47 of Set 6 | tuatapere
# Processing Record 48 of Set 6 | sakakah
# Processing Record 49 of Set 6 | tebingtinggi
# Processing Record 50 of Set 6 | mae ramat
# Processing Record 1 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 7 | playas
# Processing Record 3 of Set 7 | angoche
# Processing Record 4 of Set 7 | ayan
# Processing Record 5 of Set 7 | airai
# Processing Record 6 of Set 7 | hualmay
# Processing Record 7 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 7 | puerto del rosario
# Processing Record 10 of Set 7 | labuhan
# Processing Record 11 of Set 7 | aquiraz
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | trelew
# Processing Record 14 of Set 7 | palauig
# Processing Record 15 of Set 7 | coquimbo
# Processing Record 16 of Set 7 | port lincoln
# Processing Record 17 of Set 7 | deniliquin
# Processing Record 18 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 7 | linden
# Processing Record 20 of Set 7 | nome
# Processing Record 21 of Set 7 | lagunas
# Processing Record 22 of Set 7 | zanjan
# Processing Record 23 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 7 | sandakan
# Processing Record 25 of Set 7 | wahiawa
# Processing Record 26 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 7 | that phanom
# Processing Record 28 of Set 7 | xinqing
# Processing Record 29 of Set 7 | mozarlandia
# Processing Record 30 of Set 7 | hambantota
# Processing Record 31 of Set 7 | sorland
# Processing Record 32 of Set 7 | gao
# Processing Record 33 of Set 7 | richards bay
# Processing Record 34 of Set 7 | kulu
# Processing Record 35 of Set 7 | banjar
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | mulege
# Processing Record 38 of Set 7 | bjornevatn
# Processing Record 39 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 40 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 41 of Set 7 | mangan
# Processing Record 42 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 7 | maues
# Processing Record 44 of Set 7 | kasamwa
# Processing Record 45 of Set 7 | winnemucca
# Processing Record 46 of Set 7 | mahibadhoo
# Processing Record 47 of Set 7 | kerema
# Processing Record 48 of Set 7 | northam
# Processing Record 49 of Set 7 | carutapera
# Processing Record 50 of Set 7 | yuksekova
# Processing Record 1 of Set 8 | tilichiki
# Processing Record 2 of Set 8 | villa carlos paz
# Processing Record 3 of Set 8 | talnakh
# Processing Record 4 of Set 8 | bambanglipuro
# Processing Record 5 of Set 8 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 6 of Set 8 | prieska
# Processing Record 7 of Set 8 | porto belo
# Processing Record 8 of Set 8 | kuito
# Processing Record 9 of Set 8 | san ramon
# Processing Record 10 of Set 8 | kahului
# Processing Record 11 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 8 | victoria
# Processing Record 13 of Set 8 | hami
# Processing Record 14 of Set 8 | bria
# Processing Record 15 of Set 8 | santa maria
# Processing Record 16 of Set 8 | ternate
# Processing Record 17 of Set 8 | huarmey
# Processing Record 18 of Set 8 | vagur
# Processing Record 19 of Set 8 | dali
# Processing Record 20 of Set 8 | moorhead
# Processing Record 21 of Set 8 | ulaangom
# Processing Record 22 of Set 8 | metro
# Processing Record 23 of Set 8 | guekedou
# City not found. Skipping...
# Processing Record 24 of Set 8 | constitucion
# Processing Record 25 of Set 8 | lompoc
# Processing Record 26 of Set 8 | daru
# Processing Record 27 of Set 8 | mvangue
# Processing Record 28 of Set 8 | corpus christi
# Processing Record 29 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 8 | sabang
# Processing Record 31 of Set 8 | negombo
# Processing Record 32 of Set 8 | fortuna
# Processing Record 33 of Set 8 | ewa beach
# Processing Record 34 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | mogadishu
# Processing Record 36 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 8 | saint andrews
# Processing Record 38 of Set 8 | lonar
# Processing Record 39 of Set 8 | fuxin
# Processing Record 40 of Set 8 | aviles
# Processing Record 41 of Set 8 | sigerfjord
# City not found. Skipping...
# Processing Record 42 of Set 8 | ankang
# Processing Record 43 of Set 8 | umm kaddadah
# Processing Record 44 of Set 8 | beyneu
# Processing Record 45 of Set 8 | nieves
# Processing Record 46 of Set 8 | wajima
# Processing Record 47 of Set 8 | lukovetskiy
# Processing Record 48 of Set 8 | marfino
# Processing Record 49 of Set 8 | zyryanka
# Processing Record 50 of Set 8 | ayolas
# Processing Record 1 of Set 9 | pevek
# Processing Record 2 of Set 9 | te anau
# Processing Record 3 of Set 9 | yulara
# Processing Record 4 of Set 9 | brae
# Processing Record 5 of Set 9 | znamenskoye
# Processing Record 6 of Set 9 | queimadas
# Processing Record 7 of Set 9 | marsh harbour
# Processing Record 8 of Set 9 | chokwe
# Processing Record 9 of Set 9 | gravdal
# Processing Record 10 of Set 9 | baie-comeau
# Processing Record 11 of Set 9 | bethel
# Processing Record 12 of Set 9 | zadar
# Processing Record 13 of Set 9 | vila
# Processing Record 14 of Set 9 | sakaiminato
# Processing Record 15 of Set 9 | shimoda
# Processing Record 16 of Set 9 | codrington
# Processing Record 17 of Set 9 | biloela
# Processing Record 18 of Set 9 | bar harbor
# Processing Record 19 of Set 9 | kodinsk
# Processing Record 20 of Set 9 | acarau
# Processing Record 21 of Set 9 | svetlogorsk
# Processing Record 22 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 9 | choix
# Processing Record 24 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 25 of Set 9 | comarapa
# Processing Record 26 of Set 9 | kuli
# Processing Record 27 of Set 9 | moree
# Processing Record 28 of Set 9 | saint-francois
# Processing Record 29 of Set 9 | granada
# Processing Record 30 of Set 9 | ancud
# Processing Record 31 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 9 | holguin
# Processing Record 33 of Set 9 | washougal
# Processing Record 34 of Set 9 | araguari
# Processing Record 35 of Set 9 | liepaja
# Processing Record 36 of Set 9 | dawei
# Processing Record 37 of Set 9 | namatanai
# Processing Record 38 of Set 9 | broome
# Processing Record 39 of Set 9 | nouadhibou
# Processing Record 40 of Set 9 | san buenaventura
# Processing Record 41 of Set 9 | karasjok
# Processing Record 42 of Set 9 | narwar
# Processing Record 43 of Set 9 | pangody
# Processing Record 44 of Set 9 | multai
# Processing Record 45 of Set 9 | dukat
# Processing Record 46 of Set 9 | baghdad
# Processing Record 47 of Set 9 | linxia
# Processing Record 48 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 49 of Set 9 | pskov
# Processing Record 50 of Set 9 | cabedelo
# Processing Record 1 of Set 10 | abalak
# Processing Record 2 of Set 10 | asau
# Processing Record 3 of Set 10 | biedenkopf
# Processing Record 4 of Set 10 | igarka
# Processing Record 5 of Set 10 | pemberton
# Processing Record 6 of Set 10 | seymchan
# Processing Record 7 of Set 10 | havelock
# Processing Record 8 of Set 10 | ponta do sol
# Processing Record 9 of Set 10 | gushikawa
# Processing Record 10 of Set 10 | tarakan
# Processing Record 11 of Set 10 | tupik
# Processing Record 12 of Set 10 | camopi
# Processing Record 13 of Set 10 | coahuayana
# Processing Record 14 of Set 10 | luwuk
# Processing Record 15 of Set 10 | akdepe
# Processing Record 16 of Set 10 | katherine
# Processing Record 17 of Set 10 | himensulan
# Processing Record 18 of Set 10 | vysokaya gora
# Processing Record 19 of Set 10 | hauterive
# Processing Record 20 of Set 10 | tateyama
# Processing Record 21 of Set 10 | valkeala
# Processing Record 22 of Set 10 | antofagasta
# Processing Record 23 of Set 10 | shelburne
# Processing Record 24 of Set 10 | anloga
# Processing Record 25 of Set 10 | vilyuysk
# Processing Record 26 of Set 10 | akyab
# Processing Record 27 of Set 10 | auki
# Processing Record 28 of Set 10 | glazov
# Processing Record 29 of Set 10 | basco
# Processing Record 30 of Set 10 | adrar
# Processing Record 31 of Set 10 | ostrovnoy
# Processing Record 32 of Set 10 | wajid
# Processing Record 33 of Set 10 | tiksi
# Processing Record 34 of Set 10 | comodoro rivadavia
# Processing Record 35 of Set 10 | williamsport
# Processing Record 36 of Set 10 | bonthe
# Processing Record 37 of Set 10 | hervey bay
# Processing Record 38 of Set 10 | chanderi
# Processing Record 39 of Set 10 | odesskoye
# Processing Record 40 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 10 | tagab
# Processing Record 42 of Set 10 | urucui
# Processing Record 43 of Set 10 | neiafu
# Processing Record 44 of Set 10 | elizabeth city
# Processing Record 45 of Set 10 | seoul
# Processing Record 46 of Set 10 | marsa matruh
# Processing Record 47 of Set 10 | pisco
# Processing Record 48 of Set 10 | bugac
# Processing Record 49 of Set 10 | blackwater
# Processing Record 50 of Set 10 | dongsheng
# Processing Record 1 of Set 11 | muhos
# Processing Record 2 of Set 11 | eureka
# Processing Record 3 of Set 11 | simbahan
# Processing Record 4 of Set 11 | mhlume
# Processing Record 5 of Set 11 | gamba
# Processing Record 6 of Set 11 | valparaiso
# Processing Record 7 of Set 11 | yeppoon
# Processing Record 8 of Set 11 | talpa
# Processing Record 9 of Set 11 | homagama
# Processing Record 10 of Set 11 | pontes e lacerda
# Processing Record 11 of Set 11 | koumac
# Processing Record 12 of Set 11 | zhanaozen
# Processing Record 13 of Set 11 | sinnamary
# Processing Record 14 of Set 11 | wawa
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | mumbwa
# Processing Record 17 of Set 11 | bay saint louis
# Processing Record 18 of Set 11 | bandarbeyla
# Processing Record 19 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 11 | frunze
# Processing Record 21 of Set 11 | nedjo
# Processing Record 22 of Set 11 | katsuura
# Processing Record 23 of Set 11 | puerto narino
# Processing Record 24 of Set 11 | barentu
# Processing Record 25 of Set 11 | santa isabel do rio negro
# Processing Record 26 of Set 11 | pierre
# Processing Record 27 of Set 11 | aasiaat
# Processing Record 28 of Set 11 | maningrida
# Processing Record 29 of Set 11 | troitskoye
# Processing Record 30 of Set 11 | iskateley
# Processing Record 31 of Set 11 | alibag
# Processing Record 32 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 11 | bogo
# Processing Record 34 of Set 11 | ojinaga
# Processing Record 35 of Set 11 | tirthahalli
# Processing Record 36 of Set 11 | hobyo
# Processing Record 37 of Set 11 | poum
# Processing Record 38 of Set 11 | wangkui
# Processing Record 39 of Set 11 | berbera
# Processing Record 40 of Set 11 | primero de enero
# Processing Record 41 of Set 11 | marawi
# Processing Record 42 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 11 | torbay
# Processing Record 44 of Set 11 | mikhaylovka
# Processing Record 45 of Set 11 | port-cartier
# Processing Record 46 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 47 of Set 11 | kokkola
# Processing Record 48 of Set 11 | sri aman
# Processing Record 49 of Set 11 | acari
# Processing Record 50 of Set 11 | rapar
# Processing Record 1 of Set 12 | juruti
# Processing Record 2 of Set 12 | tiruchchendur
# Processing Record 3 of Set 12 | khani
# Processing Record 4 of Set 12 | atasu
# Processing Record 5 of Set 12 | misratah
# Processing Record 6 of Set 12 | manadhoo
# Processing Record 7 of Set 12 | abha
# Processing Record 8 of Set 12 | touros
# Processing Record 9 of Set 12 | conceicao do araguaia
# Processing Record 10 of Set 12 | phan thiet
# Processing Record 11 of Set 12 | san pedro
# Processing Record 12 of Set 12 | kamaishi
# Processing Record 13 of Set 12 | vaitape
# Processing Record 14 of Set 12 | jalu
# Processing Record 15 of Set 12 | yondo
# Processing Record 16 of Set 12 | novaya lyalya
# Processing Record 17 of Set 12 | boddam
# Processing Record 18 of Set 12 | homer
# Processing Record 19 of Set 12 | sioux lookout
# Processing Record 20 of Set 12 | mehamn
# Processing Record 21 of Set 12 | dingle
# Processing Record 22 of Set 12 | tankhoy
# Processing Record 23 of Set 12 | turinskaya sloboda
# Processing Record 24 of Set 12 | mackay
# Processing Record 25 of Set 12 | athabasca
# Processing Record 26 of Set 12 | dhankuta
# Processing Record 27 of Set 12 | colombo
# Processing Record 28 of Set 12 | belaya gora
# Processing Record 29 of Set 12 | dunedin
# Processing Record 30 of Set 12 | narodychi
# Processing Record 31 of Set 12 | ossora
# Processing Record 32 of Set 12 | zhigansk
# Processing Record 33 of Set 12 | manzanillo
# Processing Record 34 of Set 12 | half moon bay
# Processing Record 35 of Set 12 | tara
# Processing Record 36 of Set 12 | maniitsoq
# Processing Record 37 of Set 12 | lafia
# Processing Record 38 of Set 12 | enshi
# Processing Record 39 of Set 12 | ucluelet
# Processing Record 40 of Set 12 | bacolod
# Processing Record 41 of Set 12 | bathsheba
# Processing Record 42 of Set 12 | klaksvik
# Processing Record 43 of Set 12 | san-pedro
# Processing Record 44 of Set 12 | necochea
# Processing Record 45 of Set 12 | teya
# Processing Record 46 of Set 12 | sokna
# Processing Record 47 of Set 12 | lakes entrance
# Processing Record 48 of Set 12 | crailsheim
# Processing Record 49 of Set 12 | fairbanks
# Processing Record 50 of Set 12 | balkanabat
# Processing Record 1 of Set 13 | buin
# Processing Record 2 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 13 | meulaboh
# Processing Record 4 of Set 13 | atar
# Processing Record 5 of Set 13 | kijang
# Processing Record 6 of Set 13 | ous
# Processing Record 7 of Set 13 | ilo
# Processing Record 8 of Set 13 | san luis
# Processing Record 9 of Set 13 | mae hong son
# Processing Record 10 of Set 13 | champerico
# Processing Record 11 of Set 13 | kautokeino
# Processing Record 12 of Set 13 | shingu
# Processing Record 13 of Set 13 | yelizovo
# Processing Record 14 of Set 13 | hopelchen
# Processing Record 15 of Set 13 | smithers
# Processing Record 16 of Set 13 | padova
# Processing Record 17 of Set 13 | pangnirtung
# Processing Record 18 of Set 13 | pichayevo
# Processing Record 19 of Set 13 | biskamzha
# Processing Record 20 of Set 13 | cacu
# Processing Record 21 of Set 13 | poros
# Processing Record 22 of Set 13 | ocampo
# Processing Record 23 of Set 13 | capelinha
# Processing Record 24 of Set 13 | maraa
# Processing Record 25 of Set 13 | diamantino
# Processing Record 26 of Set 13 | anito
# Processing Record 27 of Set 13 | macau
# Processing Record 28 of Set 13 | hamilton
# Processing Record 29 of Set 13 | limulunga
# Processing Record 30 of Set 13 | eufaula
# Processing Record 31 of Set 13 | cairns
# Processing Record 32 of Set 13 | tinskoy
# Processing Record 33 of Set 13 | iracoubo
# Processing Record 34 of Set 13 | williams lake
# Processing Record 35 of Set 13 | isugod
# Processing Record 36 of Set 13 | charters towers
# Processing Record 37 of Set 13 | waddan
# Processing Record 38 of Set 13 | marzuq
# Processing Record 39 of Set 13 | meridian
# Processing Record 40 of Set 13 | pabianice
# Processing Record 41 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 13 | havoysund
# Processing Record 43 of Set 13 | atbasar
# Processing Record 44 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 13 | lata
# Processing Record 46 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 47 of Set 13 | gweta
# Processing Record 48 of Set 13 | himora
# City not found. Skipping...
# Processing Record 49 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 13 | tefe
# Processing Record 1 of Set 14 | rio grande
# Processing Record 2 of Set 14 | anadyr
# Processing Record 3 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 4 of Set 14 | keetmanshoop
# Processing Record 5 of Set 14 | ahuimanu
# Processing Record 6 of Set 14 | ouesso
# Processing Record 7 of Set 14 | tlanalapan
# Processing Record 8 of Set 14 | karachi
# Processing Record 9 of Set 14 | sandviken
# Processing Record 10 of Set 14 | el tigre
# Processing Record 11 of Set 14 | ziro
# Processing Record 12 of Set 14 | khandbari
# Processing Record 13 of Set 14 | grande-riviere
# City not found. Skipping...
# Processing Record 14 of Set 14 | lorengau
# Processing Record 15 of Set 14 | beringovskiy
# Processing Record 16 of Set 14 | ouadda
# Processing Record 17 of Set 14 | aksarka
# Processing Record 18 of Set 14 | union
# Processing Record 19 of Set 14 | tsabong
# Processing Record 20 of Set 14 | brandon
# Processing Record 21 of Set 14 | uuemoisa
# Processing Record 22 of Set 14 | aden
# Processing Record 23 of Set 14 | biak
# Processing Record 24 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 14 | jiangkou
# Processing Record 26 of Set 14 | egvekinot
# Processing Record 27 of Set 14 | husavik
# Processing Record 28 of Set 14 | lima
# Processing Record 29 of Set 14 | soke
# Processing Record 30 of Set 14 | itoman
# Processing Record 31 of Set 14 | porto walter
# Processing Record 32 of Set 14 | chapais
# Processing Record 33 of Set 14 | bereda
# Processing Record 34 of Set 14 | kingsville
# Processing Record 35 of Set 14 | worland
# Processing Record 36 of Set 14 | severnyy
# Processing Record 37 of Set 14 | sur
# Processing Record 38 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 14 | sao paulo de olivenca
# Processing Record 40 of Set 14 | kidal
# Processing Record 41 of Set 14 | dawlatabad
# Processing Record 42 of Set 14 | ladario
# Processing Record 43 of Set 14 | burnie
# Processing Record 44 of Set 14 | waingapu
# Processing Record 45 of Set 14 | allanmyo
# City not found. Skipping...
# Processing Record 46 of Set 14 | ujjain
# Processing Record 47 of Set 14 | port-gentil
# Processing Record 48 of Set 14 | baykit
# Processing Record 49 of Set 14 | pokosnoye
# Processing Record 50 of Set 14 | yatou
# Processing Record 1 of Set 15 | jaumave
# Processing Record 2 of Set 15 | maun
# Processing Record 3 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 15 | eldoret
# Processing Record 5 of Set 15 | leh
# Processing Record 6 of Set 15 | petropavlovka
# Processing Record 7 of Set 15 | wanaka
# Processing Record 8 of Set 15 | jacksonville beach
# Processing Record 9 of Set 15 | piryion
# City not found. Skipping...
# Processing Record 10 of Set 15 | eidfjord
# Processing Record 11 of Set 15 | havre-saint-pierre
# Processing Record 12 of Set 15 | placido de castro
# Processing Record 13 of Set 15 | sobolevo
# Processing Record 14 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 15 of Set 15 | smidovich
# Processing Record 16 of Set 15 | atherton
# Processing Record 17 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 15 | chardara
# Processing Record 19 of Set 15 | binzhou
# Processing Record 20 of Set 15 | krusevac
# Processing Record 21 of Set 15 | urumqi
# Processing Record 22 of Set 15 | matehuala
# Processing Record 23 of Set 15 | ballina
# Processing Record 24 of Set 15 | ilesha
# Processing Record 25 of Set 15 | mezen
# Processing Record 26 of Set 15 | ibra
# Processing Record 27 of Set 15 | camacha
# Processing Record 28 of Set 15 | saint-michel-des-saints
# Processing Record 29 of Set 15 | alquizar
# Processing Record 30 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 15 | jian
# Processing Record 32 of Set 15 | dunmore town
# Processing Record 33 of Set 15 | koszalin
# Processing Record 34 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 15 | villarrica
# Processing Record 36 of Set 15 | koulikoro
# Processing Record 37 of Set 15 | harlingen
# Processing Record 38 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 39 of Set 15 | mangai
# Processing Record 40 of Set 15 | los llanos de aridane
# Processing Record 41 of Set 15 | matara
# Processing Record 42 of Set 15 | salym
# Processing Record 43 of Set 15 | barra do corda
# Processing Record 44 of Set 15 | kyren
# Processing Record 45 of Set 15 | shuangcheng
# Processing Record 46 of Set 15 | rosemount
# Processing Record 47 of Set 15 | kati
# Processing Record 48 of Set 15 | okha
# Processing Record 49 of Set 15 | bagotville
# Processing Record 50 of Set 15 | lampang
# Processing Record 1 of Set 16 | cururupu
# Processing Record 2 of Set 16 | kalabo
# Processing Record 3 of Set 16 | north bend
# Processing Record 4 of Set 16 | wanning
# Processing Record 5 of Set 16 | ilulissat
# Processing Record 6 of Set 16 | kenora
# Processing Record 7 of Set 16 | platanos
# Processing Record 8 of Set 16 | mantua
# Processing Record 9 of Set 16 | matay
# Processing Record 10 of Set 16 | aleksandrov gay
# Processing Record 11 of Set 16 | mullaitivu
# City not found. Skipping...
# Processing Record 12 of Set 16 | lyngseidet
# Processing Record 13 of Set 16 | lanxi
# Processing Record 14 of Set 16 | saint-joseph
# Processing Record 15 of Set 16 | havre
# Processing Record 16 of Set 16 | sorochinsk
# Processing Record 17 of Set 16 | tari
# Processing Record 18 of Set 16 | bara
# Processing Record 19 of Set 16 | rusape
# Processing Record 20 of Set 16 | mujiayingzi
# Processing Record 21 of Set 16 | biltine
# Processing Record 22 of Set 16 | trinidad
# Processing Record 23 of Set 16 | mayo
# Processing Record 24 of Set 16 | watertown
# Processing Record 25 of Set 16 | natal
# Processing Record 26 of Set 16 | makakilo city
# Processing Record 27 of Set 16 | balkhash
# Processing Record 28 of Set 16 | great yarmouth
# Processing Record 29 of Set 16 | formosa do rio preto
# Processing Record 30 of Set 16 | marystown
# Processing Record 31 of Set 16 | den helder
# Processing Record 32 of Set 16 | laguna
# Processing Record 33 of Set 16 | ust-nera
# Processing Record 34 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 16 | aklavik
# Processing Record 36 of Set 16 | yauya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 718

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo      US  19.7297 -155.0900     67.73        84         100
# 1          Albany      US  42.6001  -73.9662     49.08        63         100
# 2          Barrow      US  71.2906 -156.7887    -30.98       100           0
# 3         Mataura      NZ -46.1927  168.8643     51.48        90         100
# 4  Ribeira Grande      PT  38.5167  -28.7000     63.00        82          40
# 5       Cartagena      CO  10.3997  -75.5144     85.62        62           0
# 6     Tuktoyaktuk      CA  69.4541 -133.0374    -29.20        75           0
# 7           Vaini      TO -21.2000 -175.2000     78.96        94          20
# 8          Winton      US  37.3894 -120.6133     64.27        94           0
# 9       Mahebourg      MU -20.4081   57.7000     80.89        74          20
#
#    Wind Speed Current Description
# 0        0.00     overcast clouds
# 1        3.00     overcast clouds
# 2        8.05           clear sky
# 3        3.27     overcast clouds
# 4       20.71    scattered clouds
# 5        4.61           clear sky
# 6        8.05           clear sky
# 7        4.61          few clouds
# 8        0.00           clear sky
# 9        3.44          few clouds

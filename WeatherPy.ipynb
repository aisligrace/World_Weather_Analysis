# %%
cites = []

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 620

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6e49f21ff364fdff499a4f066ae649aa

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 1 | camacha
# Processing Record 2 of Set 1 | faya
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | xining
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | belushya guba
# Processing Record 7 of Set 1 | flinders
# Processing Record 8 of Set 1 | emba
# Processing Record 9 of Set 1 | conde
# Processing Record 10 of Set 1 | araouane
# Processing Record 11 of Set 1 | braniewo
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | luau
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | tezu
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | camopi
# Processing Record 19 of Set 1 | saskylakh
# Processing Record 20 of Set 1 | seoul
# Processing Record 21 of Set 1 | itatskiy
# Processing Record 22 of Set 1 | awjilah
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | srednekolymsk
# Processing Record 25 of Set 1 | krasnokamensk
# Processing Record 26 of Set 1 | solnechnyy
# Processing Record 27 of Set 1 | te anau
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | surovikino
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | amderma
# Processing Record 32 of Set 1 | kerteh
# Processing Record 33 of Set 1 | saint-augustin
# Processing Record 34 of Set 1 | vestmannaeyjar
# Processing Record 35 of Set 1 | ponta delgada
# Processing Record 36 of Set 1 | hualmay
# Processing Record 37 of Set 1 | jega
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | almeirim
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | prince rupert
# Processing Record 43 of Set 1 | arlit
# Processing Record 44 of Set 1 | jacmel
# Processing Record 45 of Set 1 | karaul
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | ust-koksa
# Processing Record 48 of Set 1 | tasiilaq
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | dingle
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | tilichiki
# Processing Record 3 of Set 2 | taltal
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | poronaysk
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | lebanon
# Processing Record 11 of Set 2 | mount gambier
# Processing Record 12 of Set 2 | sentyabrskiy
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | moron
# Processing Record 16 of Set 2 | mogadishu
# Processing Record 17 of Set 2 | novobirilyussy
# Processing Record 18 of Set 2 | isangel
# Processing Record 19 of Set 2 | comodoro rivadavia
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | lagoa
# Processing Record 22 of Set 2 | capreol
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | roma
# Processing Record 25 of Set 2 | shu
# Processing Record 26 of Set 2 | cabo san lucas
# Processing Record 27 of Set 2 | kusk
# Processing Record 28 of Set 2 | maceio
# Processing Record 29 of Set 2 | talnakh
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | sayat
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | cacoal
# Processing Record 34 of Set 2 | bereznehuvate
# Processing Record 35 of Set 2 | gunjur
# Processing Record 36 of Set 2 | neiafu
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | fairbanks
# Processing Record 39 of Set 2 | likasi
# Processing Record 40 of Set 2 | yagodnoye
# Processing Record 41 of Set 2 | yulara
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | quatre cocos
# Processing Record 44 of Set 2 | leningradskiy
# Processing Record 45 of Set 2 | goderich
# Processing Record 46 of Set 2 | alta floresta
# Processing Record 47 of Set 2 | tukrah
# Processing Record 48 of Set 2 | amazar
# Processing Record 49 of Set 2 | zhanaozen
# Processing Record 50 of Set 2 | winnemucca
# Processing Record 1 of Set 3 | broken hill
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | sioux lookout
# Processing Record 4 of Set 3 | tumannyy
# Processing Record 5 of Set 3 | altagracia de orituco
# Processing Record 6 of Set 3 | mataura
# Processing Record 7 of Set 3 | batavia
# Processing Record 8 of Set 3 | bandar-e lengeh
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | malwan
# Processing Record 11 of Set 3 | juneau
# Processing Record 12 of Set 3 | puerto escondido
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | upata
# Processing Record 17 of Set 3 | innisfail
# Processing Record 18 of Set 3 | coihaique
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | acarau
# Processing Record 21 of Set 3 | burgersdorp
# Processing Record 22 of Set 3 | attawapiskat
# Processing Record 23 of Set 3 | shaping
# Processing Record 24 of Set 3 | nova vicosa
# Processing Record 25 of Set 3 | norman wells
# Processing Record 26 of Set 3 | nanortalik
# Processing Record 27 of Set 3 | ruwi
# Processing Record 28 of Set 3 | college
# Processing Record 29 of Set 3 | krasnoselkup
# Processing Record 30 of Set 3 | muttupet
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | vostok
# Processing Record 33 of Set 3 | guelph
# Processing Record 34 of Set 3 | mys shmidta
# Processing Record 35 of Set 3 | ushtobe
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | mahibadhoo
# Processing Record 38 of Set 3 | uromi
# Processing Record 39 of Set 3 | tuktoyaktuk
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | mitsamiouli
# Processing Record 42 of Set 3 | takoradi
# Processing Record 43 of Set 3 | ponta do sol
# Processing Record 44 of Set 3 | tiznit
# Processing Record 45 of Set 3 | colwyn bay
# Processing Record 46 of Set 3 | peniche
# Processing Record 47 of Set 3 | leticia
# Processing Record 48 of Set 3 | ak-dovurak
# Processing Record 49 of Set 3 | bilma
# Processing Record 50 of Set 3 | nguiu
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | rawatsar
# Processing Record 3 of Set 4 | gwadar
# Processing Record 4 of Set 4 | misratah
# Processing Record 5 of Set 4 | yerofey pavlovich
# Processing Record 6 of Set 4 | qaqortoq
# Processing Record 7 of Set 4 | safwah
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | biltine
# Processing Record 10 of Set 4 | lasa
# Processing Record 11 of Set 4 | tungor
# Processing Record 12 of Set 4 | namibe
# Processing Record 13 of Set 4 | belaya gora
# Processing Record 14 of Set 4 | ryotsu
# Processing Record 15 of Set 4 | sarkand
# Processing Record 16 of Set 4 | paamiut
# Processing Record 17 of Set 4 | necochea
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | gurupa
# Processing Record 22 of Set 4 | eureka
# Processing Record 23 of Set 4 | shakawe
# Processing Record 24 of Set 4 | hilo
# Processing Record 25 of Set 4 | asau
# Processing Record 26 of Set 4 | tuatapere
# Processing Record 27 of Set 4 | tsihombe
# Processing Record 28 of Set 4 | mar del plata
# Processing Record 29 of Set 4 | huarmey
# Processing Record 30 of Set 4 | chokurdakh
# Processing Record 31 of Set 4 | kaitangata
# Processing Record 32 of Set 4 | richards bay
# Processing Record 33 of Set 4 | sibu
# Processing Record 34 of Set 4 | kloulklubed
# Processing Record 35 of Set 4 | kalmunai
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | vieques
# Processing Record 38 of Set 4 | adjumani
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 4 | praia da vitoria
# Processing Record 42 of Set 4 | gorontalo
# Processing Record 43 of Set 4 | flin flon
# Processing Record 44 of Set 4 | boca do acre
# Processing Record 45 of Set 4 | sao joao da barra
# Processing Record 46 of Set 4 | merritt island
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | omsukchan
# Processing Record 49 of Set 4 | chicama
# Processing Record 50 of Set 4 | ye
# Processing Record 1 of Set 5 | orhei
# Processing Record 2 of Set 5 | yangcun
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | arraial do cabo
# Processing Record 5 of Set 5 | matara
# Processing Record 6 of Set 5 | kerki
# Processing Record 7 of Set 5 | key west
# Processing Record 8 of Set 5 | linjiang
# Processing Record 9 of Set 5 | taolanaro
# Processing Record 10 of Set 5 | kurilsk
# Processing Record 11 of Set 5 | tautira
# Processing Record 12 of Set 5 | kidal
# Processing Record 13 of Set 5 | ardistan
# Processing Record 14 of Set 5 | santa isabel do rio negro
# Processing Record 15 of Set 5 | saint-paul
# Processing Record 16 of Set 5 | hobart
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | breves
# Processing Record 19 of Set 5 | ust-kamchatsk
# Processing Record 20 of Set 5 | airai
# Processing Record 21 of Set 5 | nome
# Processing Record 22 of Set 5 | cobija
# Processing Record 23 of Set 5 | vanimo
# Processing Record 24 of Set 5 | beringovskiy
# Processing Record 25 of Set 5 | dengzhou
# Processing Record 26 of Set 5 | sao lourenco do sul
# Processing Record 27 of Set 5 | tura
# Processing Record 28 of Set 5 | kutum
# Processing Record 29 of Set 5 | bandarbeyla
# Processing Record 30 of Set 5 | nikolskoye
# Processing Record 31 of Set 5 | bagdarin
# Processing Record 32 of Set 5 | georgetown
# Processing Record 33 of Set 5 | koutsouras
# Processing Record 34 of Set 5 | neringa
# Processing Record 35 of Set 5 | mabaruma
# Processing Record 36 of Set 5 | haiger
# Processing Record 37 of Set 5 | bambous virieux
# Processing Record 38 of Set 5 | bridlington
# Processing Record 39 of Set 5 | zonguldak
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | sao sebastiao do paraiso
# Processing Record 42 of Set 5 | aginskoye
# Processing Record 43 of Set 5 | iqaluit
# Processing Record 44 of Set 5 | vila velha
# Processing Record 45 of Set 5 | lompoc
# Processing Record 46 of Set 5 | ust-nera
# Processing Record 47 of Set 5 | maldonado
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | santa fe
# Processing Record 50 of Set 5 | san andres
# Processing Record 1 of Set 6 | nizhneyansk
# Processing Record 2 of Set 6 | kavieng
# Processing Record 3 of Set 6 | raymondville
# Processing Record 4 of Set 6 | baleshwar
# Processing Record 5 of Set 6 | novato
# Processing Record 6 of Set 6 | dukat
# Processing Record 7 of Set 6 | kalmar
# Processing Record 8 of Set 6 | tete
# Processing Record 9 of Set 6 | constitucion
# Processing Record 10 of Set 6 | fuxin
# Processing Record 11 of Set 6 | gympie
# Processing Record 12 of Set 6 | mahaicony
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | conceicao do araguaia
# Processing Record 15 of Set 6 | grand river south east
# Processing Record 16 of Set 6 | kavasilas
# Processing Record 17 of Set 6 | vila
# Processing Record 18 of Set 6 | rawannawi
# Processing Record 19 of Set 6 | samusu
# Processing Record 20 of Set 6 | muisne
# Processing Record 21 of Set 6 | kushima
# Processing Record 22 of Set 6 | baie-comeau
# Processing Record 23 of Set 6 | naze
# Processing Record 24 of Set 6 | illoqqortoormiut
# Processing Record 25 of Set 6 | bokspits
# Processing Record 26 of Set 6 | taoudenni
# Processing Record 27 of Set 6 | aykhal
# Processing Record 28 of Set 6 | cockburn town
# Processing Record 29 of Set 6 | longyearbyen
# Processing Record 30 of Set 6 | khani
# Processing Record 31 of Set 6 | henties bay
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | russell
# Processing Record 34 of Set 6 | miri
# Processing Record 35 of Set 6 | fort nelson
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | khuzhir
# Processing Record 39 of Set 6 | kaduna
# Processing Record 40 of Set 6 | sanchi
# Processing Record 41 of Set 6 | gazli
# Processing Record 42 of Set 6 | chapais
# Processing Record 43 of Set 6 | saint george
# Processing Record 44 of Set 6 | umm jarr
# Processing Record 45 of Set 6 | haines junction
# Processing Record 46 of Set 6 | farmington
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | nyurba
# Processing Record 49 of Set 6 | lolua
# Processing Record 50 of Set 6 | porto walter

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# %%
# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
        print("City not found. Skipping...")
pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Reorder the columns
city_data_df = city_data_df[["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]]
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]

# %%
 city_data_df["Lat"] >= 0

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for Wind Speed', 'Wind Speed',(-50,35))

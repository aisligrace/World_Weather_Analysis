# %%
city_data = []

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6e49f21ff364fdff499a4f066ae649aa

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | asau
# Processing Record 5 of Set 1 | half moon bay
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | panorama
# Processing Record 8 of Set 1 | huarmey
# Processing Record 9 of Set 1 | macau
# Processing Record 10 of Set 1 | shakawe
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | coquimbo
# Processing Record 13 of Set 1 | kahului
# Processing Record 14 of Set 1 | umm durman
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | hopkinsville
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | faanui
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | kishi
# Processing Record 22 of Set 1 | america dourada
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | omsukchan
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | lavrentiya
# Processing Record 28 of Set 1 | lensk
# Processing Record 29 of Set 1 | lagoa
# Processing Record 30 of Set 1 | samusu
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | bundaberg
# Processing Record 34 of Set 1 | tsihombe
# Processing Record 35 of Set 1 | namuac
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | pitsunda
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | richards bay
# Processing Record 47 of Set 1 | karakendzha
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | ivybridge
# Processing Record 50 of Set 1 | mpika
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | mys shmidta
# Processing Record 3 of Set 2 | shemonaikha
# Processing Record 4 of Set 2 | kholodnyy
# Processing Record 5 of Set 2 | sao felix do xingu
# Processing Record 6 of Set 2 | tarrafal
# Processing Record 7 of Set 2 | lewistown
# Processing Record 8 of Set 2 | katsuura
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | solhan
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | belushya guba
# Processing Record 13 of Set 2 | vao
# Processing Record 14 of Set 2 | chapais
# Processing Record 15 of Set 2 | severo-yeniseyskiy
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | palabuhanratu
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | haines junction
# Processing Record 20 of Set 2 | taolanaro
# Processing Record 21 of Set 2 | sioux lookout
# Processing Record 22 of Set 2 | sobolevo
# Processing Record 23 of Set 2 | asyut
# Processing Record 24 of Set 2 | klyuchi
# Processing Record 25 of Set 2 | oranjemund
# Processing Record 26 of Set 2 | vilhena
# Processing Record 27 of Set 2 | katherine
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | natal
# Processing Record 31 of Set 2 | vardo
# Processing Record 32 of Set 2 | charters towers
# Processing Record 33 of Set 2 | westport
# Processing Record 34 of Set 2 | srednekolymsk
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | kijang
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | kruisfontein
# Processing Record 39 of Set 2 | jijiga
# Processing Record 40 of Set 2 | faya
# Processing Record 41 of Set 2 | muli
# Processing Record 42 of Set 2 | tiksi
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | ngunguru
# Processing Record 45 of Set 2 | nanpara
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | marfino
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | turukhansk
# Processing Record 50 of Set 2 | cairns
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | tabialan
# Processing Record 4 of Set 3 | miandrivazo
# Processing Record 5 of Set 3 | deer lake
# Processing Record 6 of Set 3 | san carlos del zulia
# Processing Record 7 of Set 3 | ubatuba
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | tura
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | jasper
# Processing Record 12 of Set 3 | itarema
# Processing Record 13 of Set 3 | khani
# Processing Record 14 of Set 3 | san quintin
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | miri
# Processing Record 17 of Set 3 | pacifica
# Processing Record 18 of Set 3 | batemans bay
# Processing Record 19 of Set 3 | kenai
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | beringovskiy
# Processing Record 22 of Set 3 | punto fijo
# Processing Record 23 of Set 3 | arua
# Processing Record 24 of Set 3 | illoqqortoormiut
# Processing Record 25 of Set 3 | malartic
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | northam
# Processing Record 28 of Set 3 | port-cartier
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | muleba
# Processing Record 31 of Set 3 | gunjur
# Processing Record 32 of Set 3 | esmeraldas
# Processing Record 33 of Set 3 | kingston
# Processing Record 34 of Set 3 | barentsburg
# Processing Record 35 of Set 3 | hualmay
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | karratha
# Processing Record 40 of Set 3 | aleksandrov gay
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | pangody
# Processing Record 43 of Set 3 | ust-bolsheretsk
# Processing Record 44 of Set 3 | maldonado
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | rorvik
# Processing Record 48 of Set 3 | victoria point
# Processing Record 49 of Set 3 | naze
# Processing Record 50 of Set 3 | aksu
# Processing Record 1 of Set 4 | sisimiut
# Processing Record 2 of Set 4 | popondetta
# Processing Record 3 of Set 4 | yellowknife
# Processing Record 4 of Set 4 | kathmandu
# Processing Record 5 of Set 4 | rocha
# Processing Record 6 of Set 4 | jardim
# Processing Record 7 of Set 4 | boyolangu
# Processing Record 8 of Set 4 | mehamn
# Processing Record 9 of Set 4 | albany
# Processing Record 10 of Set 4 | okato
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | atar
# Processing Record 13 of Set 4 | san patricio
# Processing Record 14 of Set 4 | marienburg
# Processing Record 15 of Set 4 | sao joao da barra
# Processing Record 16 of Set 4 | sentyabrskiy
# Processing Record 17 of Set 4 | vila do maio
# Processing Record 18 of Set 4 | kihei
# Processing Record 19 of Set 4 | dibulla
# Processing Record 20 of Set 4 | wembley
# Processing Record 21 of Set 4 | barvinkove
# Processing Record 22 of Set 4 | arlit
# Processing Record 23 of Set 4 | qaanaaq
# Processing Record 24 of Set 4 | havre-saint-pierre
# Processing Record 25 of Set 4 | auki
# Processing Record 26 of Set 4 | bubaque
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | coihaique
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | thunder bay
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | fengrun
# Processing Record 34 of Set 4 | port elizabeth
# Processing Record 35 of Set 4 | stawell
# Processing Record 36 of Set 4 | minsk
# Processing Record 37 of Set 4 | esmeralda
# Processing Record 38 of Set 4 | frisco
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | arrifes
# Processing Record 41 of Set 4 | verkhnevilyuysk
# Processing Record 42 of Set 4 | sabratah
# Processing Record 43 of Set 4 | namatanai
# Processing Record 44 of Set 4 | porecatu
# Processing Record 45 of Set 4 | belyy yar
# Processing Record 46 of Set 4 | roma
# Processing Record 47 of Set 4 | namibe
# Processing Record 48 of Set 4 | san vicente
# Processing Record 49 of Set 4 | portland
# Processing Record 50 of Set 4 | mogadishu
# Processing Record 1 of Set 5 | grindavik
# Processing Record 2 of Set 5 | norsup
# Processing Record 3 of Set 5 | paradwip
# Processing Record 4 of Set 5 | boralday
# Processing Record 5 of Set 5 | rio verde de mato grosso
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | matara
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | shache
# Processing Record 10 of Set 5 | saint-paul
# Processing Record 11 of Set 5 | port-gentil
# Processing Record 12 of Set 5 | hovd
# Processing Record 13 of Set 5 | marrakesh
# Processing Record 14 of Set 5 | amderma
# Processing Record 15 of Set 5 | noumea
# Processing Record 16 of Set 5 | sungaipenuh
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | ranong
# Processing Record 19 of Set 5 | boali
# Processing Record 20 of Set 5 | itoman
# Processing Record 21 of Set 5 | san cristobal
# Processing Record 22 of Set 5 | gardan diwal
# Processing Record 23 of Set 5 | saint-pierre
# Processing Record 24 of Set 5 | middle island
# Processing Record 25 of Set 5 | havelock
# Processing Record 26 of Set 5 | teguise
# Processing Record 27 of Set 5 | forio
# Processing Record 28 of Set 5 | la asuncion
# Processing Record 29 of Set 5 | belmonte
# Processing Record 30 of Set 5 | mar del plata
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | pervomayskoye
# Processing Record 33 of Set 5 | santa maria
# Processing Record 34 of Set 5 | tarakan
# Processing Record 35 of Set 5 | rushden
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | liwale
# Processing Record 38 of Set 5 | rincon
# Processing Record 39 of Set 5 | pimentel
# Processing Record 40 of Set 5 | buala
# Processing Record 41 of Set 5 | portoferraio
# Processing Record 42 of Set 5 | kamenskoye
# Processing Record 43 of Set 5 | rathdrum
# Processing Record 44 of Set 5 | avera
# Processing Record 45 of Set 5 | guerrero negro
# Processing Record 46 of Set 5 | saskylakh
# Processing Record 47 of Set 5 | payson
# Processing Record 48 of Set 5 | waipawa
# Processing Record 49 of Set 5 | dourbali
# Processing Record 50 of Set 5 | port lincoln
# Processing Record 1 of Set 6 | nanortalik
# Processing Record 2 of Set 6 | sharanga
# Processing Record 3 of Set 6 | rawson
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | antofagasta
# Processing Record 6 of Set 6 | viedma
# Processing Record 7 of Set 6 | kamina
# Processing Record 8 of Set 6 | altay
# Processing Record 9 of Set 6 | fairbanks
# Processing Record 10 of Set 6 | rincon de la victoria
# Processing Record 11 of Set 6 | linhares
# Processing Record 12 of Set 6 | beaupre
# Processing Record 13 of Set 6 | praia da vitoria
# Processing Record 14 of Set 6 | namie
# Processing Record 15 of Set 6 | saint-joseph
# Processing Record 16 of Set 6 | blagoyevo
# Processing Record 17 of Set 6 | xining
# Processing Record 18 of Set 6 | yuci
# Processing Record 19 of Set 6 | pasni
# Processing Record 20 of Set 6 | mosquera
# Processing Record 21 of Set 6 | gigmoto
# Processing Record 22 of Set 6 | lebu
# Processing Record 23 of Set 6 | saint-philippe
# Processing Record 24 of Set 6 | saleaula
# Processing Record 25 of Set 6 | luanda
# Processing Record 26 of Set 6 | birao
# Processing Record 27 of Set 6 | oparino
# Processing Record 28 of Set 6 | houston
# Processing Record 29 of Set 6 | lazaro cardenas
# Processing Record 30 of Set 6 | mirabad
# Processing Record 31 of Set 6 | maragogi
# Processing Record 32 of Set 6 | mana
# Processing Record 33 of Set 6 | shingu
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | maraa
# Processing Record 36 of Set 6 | kununurra
# Processing Record 37 of Set 6 | taltal
# Processing Record 38 of Set 6 | alfredo chaves
# Processing Record 39 of Set 6 | molteno
# Processing Record 40 of Set 6 | taman
# Processing Record 41 of Set 6 | boa vista
# Processing Record 42 of Set 6 | kuhestan
# Processing Record 43 of Set 6 | dunedin
# Processing Record 44 of Set 6 | sydney
# Processing Record 45 of Set 6 | el tocuyo
# Processing Record 46 of Set 6 | xichang
# Processing Record 47 of Set 6 | soledade
# Processing Record 48 of Set 6 | mahonda
# Processing Record 49 of Set 6 | foumban
# Processing Record 50 of Set 6 | hammerfest
# Processing Record 1 of Set 7 | kamenka
# Processing Record 2 of Set 7 | tabuk
# Processing Record 3 of Set 7 | nyzhni sirohozy
# Processing Record 4 of Set 7 | ginda
# Processing Record 5 of Set 7 | port hardy
# Processing Record 6 of Set 7 | andenes
# Processing Record 7 of Set 7 | touros
# Processing Record 8 of Set 7 | margate
# Processing Record 9 of Set 7 | pisco
# Processing Record 10 of Set 7 | bethel
# Processing Record 11 of Set 7 | cherskiy
# Processing Record 12 of Set 7 | mitsamiouli
# Processing Record 13 of Set 7 | bambanglipuro
# Processing Record 14 of Set 7 | emilio carranza
# Processing Record 15 of Set 7 | sitka
# Processing Record 16 of Set 7 | anadyr
# Processing Record 17 of Set 7 | mladenovac
# Processing Record 18 of Set 7 | canutama
# Processing Record 19 of Set 7 | bumba
# Processing Record 20 of Set 7 | borogontsy
# Processing Record 21 of Set 7 | salalah
# Processing Record 22 of Set 7 | imbituba
# Processing Record 23 of Set 7 | kefamenanu
# Processing Record 24 of Set 7 | sechura
# Processing Record 25 of Set 7 | ninghai
# Processing Record 26 of Set 7 | altamira
# Processing Record 27 of Set 7 | wittmund
# Processing Record 28 of Set 7 | hithadhoo
# Processing Record 29 of Set 7 | kawana waters
# Processing Record 30 of Set 7 | fez
# Processing Record 31 of Set 7 | uchkeken
# Processing Record 32 of Set 7 | ugoofaaru
# Processing Record 33 of Set 7 | codrington
# Processing Record 34 of Set 7 | ritchie
# Processing Record 35 of Set 7 | amapa
# Processing Record 36 of Set 7 | emerald
# Processing Record 37 of Set 7 | nishihara
# Processing Record 38 of Set 7 | oudtshoorn
# Processing Record 39 of Set 7 | lachi
# Processing Record 40 of Set 7 | preobrazheniye
# Processing Record 41 of Set 7 | eldorado
# Processing Record 42 of Set 7 | malwan
# Processing Record 43 of Set 7 | narsaq
# Processing Record 44 of Set 7 | phan thiet
# Processing Record 45 of Set 7 | caravelas
# Processing Record 46 of Set 7 | zavodouspenskoye
# Processing Record 47 of Set 7 | laguna
# Processing Record 48 of Set 7 | shwebo
# Processing Record 49 of Set 7 | nantucket
# Processing Record 50 of Set 7 | medicine hat

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# %%
# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
        print("City not found. Skipping...")
pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

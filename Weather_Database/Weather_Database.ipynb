# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1f21a9c005f2d70a6053bd7288d45bd'

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 1 | chipinge
# Processing Record 4 of Set 1 | rorvik
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | hanzhong
# Processing Record 8 of Set 1 | kirakira
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | cidreira
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | saint john
# Processing Record 19 of Set 1 | prince george
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | brufut
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | sakakah
# Processing Record 25 of Set 1 | saint-augustin
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | nueva loja
# Processing Record 28 of Set 1 | mandalgovi
# Processing Record 29 of Set 1 | zaykovo
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | hasaki
# Processing Record 33 of Set 1 | padang
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | treinta y tres
# Processing Record 36 of Set 1 | sibolga
# Processing Record 37 of Set 1 | djibo
# Processing Record 38 of Set 1 | poplar bluff
# Processing Record 39 of Set 1 | novoagansk
# Processing Record 40 of Set 1 | port keats
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | matara
# Processing Record 44 of Set 1 | pisco
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | praia
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | gresham
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | stepnyak
# Processing Record 1 of Set 2 | buarcos
# Processing Record 2 of Set 2 | rehoboth
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | nur
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | port-cartier
# Processing Record 7 of Set 2 | kencong
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | luderitz
# Processing Record 10 of Set 2 | coihaique
# Processing Record 11 of Set 2 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | soyo
# Processing Record 14 of Set 2 | leh
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | birao
# Processing Record 19 of Set 2 | pierre
# Processing Record 20 of Set 2 | shubarshi
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | roura
# Processing Record 23 of Set 2 | abdanan
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | coquimbo
# Processing Record 26 of Set 2 | karoi
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | kamenka
# Processing Record 29 of Set 2 | umm kaddadah
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | genoa
# Processing Record 34 of Set 2 | watsa
# Processing Record 35 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | comodoro rivadavia
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 2 | irituia
# Processing Record 43 of Set 2 | thinadhoo
# Processing Record 44 of Set 2 | santa vitoria
# Processing Record 45 of Set 2 | itarema
# Processing Record 46 of Set 2 | aswan
# Processing Record 47 of Set 2 | baruun-urt
# Processing Record 48 of Set 2 | carupano
# Processing Record 49 of Set 2 | lisala
# Processing Record 50 of Set 2 | kenai
# Processing Record 1 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 3 | isangel
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | santo antonio do sudoeste
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | torrington
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | la orilla
# Processing Record 11 of Set 3 | kavaratti
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | colares
# Processing Record 15 of Set 3 | vila velha
# Processing Record 16 of Set 3 | bathsheba
# Processing Record 17 of Set 3 | solnechnyy
# Processing Record 18 of Set 3 | harper
# Processing Record 19 of Set 3 | konevo
# Processing Record 20 of Set 3 | tenenkou
# Processing Record 21 of Set 3 | kirs
# Processing Record 22 of Set 3 | sobolevo
# Processing Record 23 of Set 3 | freeport
# Processing Record 24 of Set 3 | nouadhibou
# Processing Record 25 of Set 3 | yenangyaung
# Processing Record 26 of Set 3 | hobart
# Processing Record 27 of Set 3 | mogadishu
# Processing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 3 | kaliua
# Processing Record 30 of Set 3 | souillac
# Processing Record 31 of Set 3 | turukhansk
# Processing Record 32 of Set 3 | pimampiro
# Processing Record 33 of Set 3 | kambove
# Processing Record 34 of Set 3 | azangaro
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | sitka
# Processing Record 37 of Set 3 | haukipudas
# Processing Record 38 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 39 of Set 3 | hilo
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | salgueiro
# Processing Record 42 of Set 3 | valdemarpils
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | ornskoldsvik
# Processing Record 45 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 3 | aklavik
# Processing Record 47 of Set 3 | puerto princesa
# Processing Record 48 of Set 3 | road town
# Processing Record 49 of Set 3 | den helder
# Processing Record 50 of Set 3 | mpongwe
# Processing Record 1 of Set 4 | pangnirtung
# Processing Record 2 of Set 4 | malindi
# Processing Record 3 of Set 4 | borborema
# Processing Record 4 of Set 4 | vanimo
# Processing Record 5 of Set 4 | bratsk
# Processing Record 6 of Set 4 | nouakchott
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | general pico
# Processing Record 9 of Set 4 | portland
# Processing Record 10 of Set 4 | otjimbingwe
# Processing Record 11 of Set 4 | tirumullaivasal
# Processing Record 12 of Set 4 | atuona
# Processing Record 13 of Set 4 | constitucion
# Processing Record 14 of Set 4 | coos bay
# Processing Record 15 of Set 4 | kapaa
# Processing Record 16 of Set 4 | pontianak
# Processing Record 17 of Set 4 | ambon
# Processing Record 18 of Set 4 | kahului
# Processing Record 19 of Set 4 | qaanaaq
# Processing Record 20 of Set 4 | pevek
# Processing Record 21 of Set 4 | skaudvile
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | sydney
# Processing Record 24 of Set 4 | imperial beach
# Processing Record 25 of Set 4 | stornoway
# Processing Record 26 of Set 4 | bogorodskoye
# Processing Record 27 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 28 of Set 4 | kamen-rybolov
# Processing Record 29 of Set 4 | banjar
# Processing Record 30 of Set 4 | marzuq
# Processing Record 31 of Set 4 | nishihara
# Processing Record 32 of Set 4 | mar del plata
# Processing Record 33 of Set 4 | banes
# Processing Record 34 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 4 | codrington
# Processing Record 36 of Set 4 | belmonte
# Processing Record 37 of Set 4 | hualmay
# Processing Record 38 of Set 4 | la ronge
# Processing Record 39 of Set 4 | dorado
# Processing Record 40 of Set 4 | kaitangata
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | balatonfured
# Processing Record 43 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 4 | labuhan
# Processing Record 45 of Set 4 | doha
# Processing Record 46 of Set 4 | kainantu
# Processing Record 47 of Set 4 | san patricio
# Processing Record 48 of Set 4 | deniliquin
# Processing Record 49 of Set 4 | bengkulu
# Processing Record 50 of Set 4 | asau
# Processing Record 1 of Set 5 | caravelas
# Processing Record 2 of Set 5 | ust-ilimsk
# Processing Record 3 of Set 5 | tarsus
# Processing Record 4 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 5 | malanje
# Processing Record 6 of Set 5 | upernavik
# Processing Record 7 of Set 5 | itanhem
# Processing Record 8 of Set 5 | safaqis
# City not found. Skipping...
# Processing Record 9 of Set 5 | new norfolk
# Processing Record 10 of Set 5 | port alfred
# Processing Record 11 of Set 5 | hofn
# Processing Record 12 of Set 5 | edgewater
# Processing Record 13 of Set 5 | rio hato
# Processing Record 14 of Set 5 | quatre cocos
# Processing Record 15 of Set 5 | hithadhoo
# Processing Record 16 of Set 5 | poum
# Processing Record 17 of Set 5 | veraval
# Processing Record 18 of Set 5 | hobyo
# Processing Record 19 of Set 5 | kazachinskoye
# Processing Record 20 of Set 5 | borama
# City not found. Skipping...
# Processing Record 21 of Set 5 | verkh-usugli
# Processing Record 22 of Set 5 | mulchen
# Processing Record 23 of Set 5 | addi ugri
# City not found. Skipping...
# Processing Record 24 of Set 5 | barguzin
# Processing Record 25 of Set 5 | tuktoyaktuk
# Processing Record 26 of Set 5 | te anau
# Processing Record 27 of Set 5 | taseyevo
# Processing Record 28 of Set 5 | ahipara
# Processing Record 29 of Set 5 | saint-philippe
# Processing Record 30 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 5 | kasongo-lunda
# Processing Record 32 of Set 5 | ahuimanu
# Processing Record 33 of Set 5 | forio
# Processing Record 34 of Set 5 | dryden
# Processing Record 35 of Set 5 | yuryevets
# Processing Record 36 of Set 5 | correntina
# Processing Record 37 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 5 | mrakovo
# Processing Record 39 of Set 5 | palu
# Processing Record 40 of Set 5 | fergus falls
# Processing Record 41 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 42 of Set 5 | haines junction
# Processing Record 43 of Set 5 | flin flon
# Processing Record 44 of Set 5 | sredniy ikorets
# Processing Record 45 of Set 5 | port elizabeth
# Processing Record 46 of Set 5 | bismarck
# Processing Record 47 of Set 5 | guerrero negro
# Processing Record 48 of Set 5 | katsuura
# Processing Record 49 of Set 5 | maldonado
# Processing Record 50 of Set 5 | ust-kuyga
# Processing Record 1 of Set 6 | turan
# Processing Record 2 of Set 6 | kavieng
# Processing Record 3 of Set 6 | hovd
# Processing Record 4 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 6 | olga
# Processing Record 6 of Set 6 | hami
# Processing Record 7 of Set 6 | bilma
# Processing Record 8 of Set 6 | abu samrah
# Processing Record 9 of Set 6 | chumikan
# Processing Record 10 of Set 6 | carmarthen
# Processing Record 11 of Set 6 | perth
# Processing Record 12 of Set 6 | tsabong
# Processing Record 13 of Set 6 | luena
# Processing Record 14 of Set 6 | porto walter
# Processing Record 15 of Set 6 | banda aceh
# Processing Record 16 of Set 6 | conde
# Processing Record 17 of Set 6 | vostok
# Processing Record 18 of Set 6 | bowen
# Processing Record 19 of Set 6 | lensk
# Processing Record 20 of Set 6 | mandan
# Processing Record 21 of Set 6 | pafos
# Processing Record 22 of Set 6 | klaksvik
# Processing Record 23 of Set 6 | east london
# Processing Record 24 of Set 6 | kongolo
# Processing Record 25 of Set 6 | bambous virieux
# Processing Record 26 of Set 6 | pingshan
# Processing Record 27 of Set 6 | songjianghe
# Processing Record 28 of Set 6 | esperance
# Processing Record 29 of Set 6 | kovdor
# Processing Record 30 of Set 6 | bardiyah
# Processing Record 31 of Set 6 | salamiyah
# Processing Record 32 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 6 | peterhead
# Processing Record 34 of Set 6 | olafsvik
# Processing Record 35 of Set 6 | kalakamati
# Processing Record 36 of Set 6 | xocasan
# City not found. Skipping...
# Processing Record 37 of Set 6 | savelugu
# Processing Record 38 of Set 6 | saldanha
# Processing Record 39 of Set 6 | kisangani
# Processing Record 40 of Set 6 | havre-saint-pierre
# Processing Record 41 of Set 6 | ostrovnoy
# Processing Record 42 of Set 6 | kristiansund
# Processing Record 43 of Set 6 | cotonou
# Processing Record 44 of Set 6 | zhoucheng
# Processing Record 45 of Set 6 | naryan-mar
# Processing Record 46 of Set 6 | latung
# Processing Record 47 of Set 6 | bud
# Processing Record 48 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 6 | chuy
# Processing Record 50 of Set 6 | laguna
# Processing Record 1 of Set 7 | ilulissat
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | tocopilla
# Processing Record 4 of Set 7 | mikhaylovskoye
# Processing Record 5 of Set 7 | lazaro cardenas
# Processing Record 6 of Set 7 | lasa
# Processing Record 7 of Set 7 | outjo
# Processing Record 8 of Set 7 | vestmannaeyjar
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | araguaina
# Processing Record 11 of Set 7 | meshchovsk
# Processing Record 12 of Set 7 | oranjemund
# Processing Record 13 of Set 7 | khandyga
# Processing Record 14 of Set 7 | nanortalik
# Processing Record 15 of Set 7 | opuwo
# Processing Record 16 of Set 7 | antofagasta
# Processing Record 17 of Set 7 | sola
# Processing Record 18 of Set 7 | vetlanda
# Processing Record 19 of Set 7 | zhezkazgan
# Processing Record 20 of Set 7 | anadyr
# Processing Record 21 of Set 7 | zyryanka
# Processing Record 22 of Set 7 | pitimbu
# Processing Record 23 of Set 7 | bayburt
# Processing Record 24 of Set 7 | niteroi
# Processing Record 25 of Set 7 | leningradskiy
# Processing Record 26 of Set 7 | quepos
# Processing Record 27 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 28 of Set 7 | guanare
# Processing Record 29 of Set 7 | bedworth
# Processing Record 30 of Set 7 | taltal
# Processing Record 31 of Set 7 | maningrida
# Processing Record 32 of Set 7 | severo-kurilsk
# Processing Record 33 of Set 7 | catalao
# Processing Record 34 of Set 7 | kendari
# Processing Record 35 of Set 7 | goulburn
# Processing Record 36 of Set 7 | maniwaki
# Processing Record 37 of Set 7 | dunedin
# Processing Record 38 of Set 7 | kupang
# Processing Record 39 of Set 7 | poli
# Processing Record 40 of Set 7 | venado tuerto
# Processing Record 41 of Set 7 | faya
# Processing Record 42 of Set 7 | rundu
# Processing Record 43 of Set 7 | mananjary
# Processing Record 44 of Set 7 | huarmey
# Processing Record 45 of Set 7 | saint-francois
# Processing Record 46 of Set 7 | tacoronte
# Processing Record 47 of Set 7 | luanda
# Processing Record 48 of Set 7 | touros
# Processing Record 49 of Set 7 | ust-maya
# Processing Record 50 of Set 7 | kumla
# Processing Record 1 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 8 | karratha
# Processing Record 3 of Set 8 | powell river
# Processing Record 4 of Set 8 | mporokoso
# Processing Record 5 of Set 8 | longyearbyen
# Processing Record 6 of Set 8 | pemba
# Processing Record 7 of Set 8 | rawson
# Processing Record 8 of Set 8 | ishigaki
# Processing Record 9 of Set 8 | ravar
# Processing Record 10 of Set 8 | saint george
# Processing Record 11 of Set 8 | rocky mount
# Processing Record 12 of Set 8 | rio grande
# Processing Record 13 of Set 8 | alice springs
# Processing Record 14 of Set 8 | nokaneng
# Processing Record 15 of Set 8 | basco
# Processing Record 16 of Set 8 | pappinisseri
# Processing Record 17 of Set 8 | dali
# Processing Record 18 of Set 8 | amboasary
# Processing Record 19 of Set 8 | lebu
# Processing Record 20 of Set 8 | mataram
# Processing Record 21 of Set 8 | alofi
# Processing Record 22 of Set 8 | salta
# Processing Record 23 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 8 | vardo
# Processing Record 26 of Set 8 | el dorado
# Processing Record 27 of Set 8 | vitimskiy
# City not found. Skipping...
# Processing Record 28 of Set 8 | acajutla
# Processing Record 29 of Set 8 | wadi maliz
# Processing Record 30 of Set 8 | avera
# Processing Record 31 of Set 8 | kroya
# Processing Record 32 of Set 8 | camapua
# Processing Record 33 of Set 8 | shiyan
# Processing Record 34 of Set 8 | maracaibo
# Processing Record 35 of Set 8 | bayir
# Processing Record 36 of Set 8 | salalah
# Processing Record 37 of Set 8 | port hedland
# Processing Record 38 of Set 8 | kiama
# Processing Record 39 of Set 8 | tuatapere
# Processing Record 40 of Set 8 | sao miguel do araguaia
# Processing Record 41 of Set 8 | fort nelson
# Processing Record 42 of Set 8 | castro
# Processing Record 43 of Set 8 | saint-joseph
# Processing Record 44 of Set 8 | auki
# Processing Record 45 of Set 8 | yeppoon
# Processing Record 46 of Set 8 | kinablangan
# Processing Record 47 of Set 8 | akdepe
# Processing Record 48 of Set 8 | nioro
# Processing Record 49 of Set 8 | wairoa
# Processing Record 50 of Set 8 | pemangkat
# Processing Record 1 of Set 9 | vallenar
# Processing Record 2 of Set 9 | yurga
# Processing Record 3 of Set 9 | tema
# Processing Record 4 of Set 9 | rabo de peixe
# Processing Record 5 of Set 9 | goderich
# Processing Record 6 of Set 9 | camalu
# Processing Record 7 of Set 9 | olinda
# Processing Record 8 of Set 9 | bunbury
# Processing Record 9 of Set 9 | chapais
# Processing Record 10 of Set 9 | grand gaube
# Processing Record 11 of Set 9 | sangueya
# Processing Record 12 of Set 9 | carbonia
# Processing Record 13 of Set 9 | mapiripan
# Processing Record 14 of Set 9 | westport
# Processing Record 15 of Set 9 | victoria
# Processing Record 16 of Set 9 | tura
# Processing Record 17 of Set 9 | gagra
# Processing Record 18 of Set 9 | sanmenxia
# Processing Record 19 of Set 9 | namibe
# Processing Record 20 of Set 9 | cantapoy
# Processing Record 21 of Set 9 | khrustalnyy
# City not found. Skipping...
# Processing Record 22 of Set 9 | kidal
# Processing Record 23 of Set 9 | sug-aksy
# City not found. Skipping...
# Processing Record 24 of Set 9 | eagle pass
# Processing Record 25 of Set 9 | faanui
# Processing Record 26 of Set 9 | berlevag
# Processing Record 27 of Set 9 | xudat
# Processing Record 28 of Set 9 | porto santo
# Processing Record 29 of Set 9 | korla
# Processing Record 30 of Set 9 | termoli
# Processing Record 31 of Set 9 | pinheiral
# Processing Record 32 of Set 9 | razgrad
# Processing Record 33 of Set 9 | tecpan
# Processing Record 34 of Set 9 | pitsunda
# Processing Record 35 of Set 9 | hambantota
# Processing Record 36 of Set 9 | tyup
# Processing Record 37 of Set 9 | ketchikan
# Processing Record 38 of Set 9 | teacapan
# Processing Record 39 of Set 9 | nizhnevartovsk
# Processing Record 40 of Set 9 | puerto ayacucho
# Processing Record 41 of Set 9 | anaconda
# Processing Record 42 of Set 9 | cayenne
# Processing Record 43 of Set 9 | talnakh
# Processing Record 44 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 45 of Set 9 | usinsk
# Processing Record 46 of Set 9 | walvis bay
# Processing Record 47 of Set 9 | ortona
# Processing Record 48 of Set 9 | rocha
# Processing Record 49 of Set 9 | nizhniy ingash
# Processing Record 50 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 1 of Set 10 | mount gambier
# Processing Record 2 of Set 10 | linares
# Processing Record 3 of Set 10 | lagoa
# Processing Record 4 of Set 10 | austin
# Processing Record 5 of Set 10 | kalmunai
# Processing Record 6 of Set 10 | perustica
# City not found. Skipping...
# Processing Record 7 of Set 10 | nanakuli
# Processing Record 8 of Set 10 | makambako
# Processing Record 9 of Set 10 | bilibino
# Processing Record 10 of Set 10 | palauig
# Processing Record 11 of Set 10 | fairbanks
# Processing Record 12 of Set 10 | burlington
# Processing Record 13 of Set 10 | grimstad
# Processing Record 14 of Set 10 | soderhamn
# Processing Record 15 of Set 10 | qaqortoq
# Processing Record 16 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 10 | nemuro
# Processing Record 18 of Set 10 | longkou
# Processing Record 19 of Set 10 | genhe
# Processing Record 20 of Set 10 | esso
# Processing Record 21 of Set 10 | hay river
# Processing Record 22 of Set 10 | alenquer
# Processing Record 23 of Set 10 | elk
# Processing Record 24 of Set 10 | bara
# Processing Record 25 of Set 10 | tanhacu
# Processing Record 26 of Set 10 | nuuk
# Processing Record 27 of Set 10 | saint-ambroise
# Processing Record 28 of Set 10 | corning
# Processing Record 29 of Set 10 | lethem
# Processing Record 30 of Set 10 | komsomolskiy
# Processing Record 31 of Set 10 | mantua
# Processing Record 32 of Set 10 | ciudad bolivar
# Processing Record 33 of Set 10 | acapulco
# Processing Record 34 of Set 10 | fort frances
# Processing Record 35 of Set 10 | sept-iles
# Processing Record 36 of Set 10 | naldurg
# Processing Record 37 of Set 10 | lompoc
# Processing Record 38 of Set 10 | namatanai
# Processing Record 39 of Set 10 | kentville
# Processing Record 40 of Set 10 | inhambane
# Processing Record 41 of Set 10 | altamira
# Processing Record 42 of Set 10 | monte alegre
# Processing Record 43 of Set 10 | beringovskiy
# Processing Record 44 of Set 10 | yulara
# Processing Record 45 of Set 10 | gat
# Processing Record 46 of Set 10 | benguela
# Processing Record 47 of Set 10 | shakawe
# Processing Record 48 of Set 10 | tomatlan
# Processing Record 49 of Set 10 | pescara
# Processing Record 50 of Set 10 | naliya
# Processing Record 1 of Set 11 | urucara
# Processing Record 2 of Set 11 | moussoro
# Processing Record 3 of Set 11 | witbank
# Processing Record 4 of Set 11 | safaga
# Processing Record 5 of Set 11 | bereznik
# Processing Record 6 of Set 11 | nadym
# Processing Record 7 of Set 11 | tucuma
# Processing Record 8 of Set 11 | dodge city
# Processing Record 9 of Set 11 | san martin
# Processing Record 10 of Set 11 | elizabeth city
# Processing Record 11 of Set 11 | nanaimo
# Processing Record 12 of Set 11 | fairlie
# Processing Record 13 of Set 11 | winnemucca
# Processing Record 14 of Set 11 | new bern
# Processing Record 15 of Set 11 | leshukonskoye
# Processing Record 16 of Set 11 | saint anthony
# Processing Record 17 of Set 11 | prince rupert
# Processing Record 18 of Set 11 | arraias
# Processing Record 19 of Set 11 | taos
# Processing Record 20 of Set 11 | burnie
# Processing Record 21 of Set 11 | villamontes
# Processing Record 22 of Set 11 | narsaq
# Processing Record 23 of Set 11 | salisbury
# Processing Record 24 of Set 11 | belyy yar
# Processing Record 25 of Set 11 | gerash
# Processing Record 26 of Set 11 | los llanos de aridane
# Processing Record 27 of Set 11 | ucluelet
# Processing Record 28 of Set 11 | jibuti
# Processing Record 29 of Set 11 | sur
# Processing Record 30 of Set 11 | ayan
# Processing Record 31 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 11 | tambo
# Processing Record 33 of Set 11 | kapit
# Processing Record 34 of Set 11 | fortuna
# Processing Record 35 of Set 11 | lewistown
# Processing Record 36 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 37 of Set 11 | rock sound
# Processing Record 38 of Set 11 | bireun
# Processing Record 39 of Set 11 | tashara
# Processing Record 40 of Set 11 | promysla
# City not found. Skipping...
# Processing Record 41 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 11 | nizhniy tsasuchey
# Processing Record 43 of Set 11 | mashhad
# Processing Record 44 of Set 11 | sisimiut
# Processing Record 45 of Set 11 | nuevo progreso
# Processing Record 46 of Set 11 | shilovo
# Processing Record 47 of Set 11 | alekseyevsk
# Processing Record 48 of Set 11 | ambilobe
# Processing Record 49 of Set 11 | igarka
# Processing Record 50 of Set 11 | guanica
# Processing Record 1 of Set 12 | miyang
# Processing Record 2 of Set 12 | gizo
# Processing Record 3 of Set 12 | pundaguitan
# Processing Record 4 of Set 12 | kalemie
# Processing Record 5 of Set 12 | borogontsy
# Processing Record 6 of Set 12 | tsiroanomandidy
# Processing Record 7 of Set 12 | kjollefjord
# Processing Record 8 of Set 12 | savinka
# Processing Record 9 of Set 12 | senanga
# Processing Record 10 of Set 12 | pacific grove
# Processing Record 11 of Set 12 | mielec
# Processing Record 12 of Set 12 | charlestown
# Processing Record 13 of Set 12 | klyuchi
# Processing Record 14 of Set 12 | key largo
# Processing Record 15 of Set 12 | guilin
# Processing Record 16 of Set 12 | camana
# Processing Record 17 of Set 12 | banos
# Processing Record 18 of Set 12 | jalu
# Processing Record 19 of Set 12 | alcala de henares
# Processing Record 20 of Set 12 | clyde river
# Processing Record 21 of Set 12 | makarska
# Processing Record 22 of Set 12 | hudson bay
# Processing Record 23 of Set 12 | paraiso
# Processing Record 24 of Set 12 | bure
# Processing Record 25 of Set 12 | port augusta
# Processing Record 26 of Set 12 | richards bay
# Processing Record 27 of Set 12 | evensk
# Processing Record 28 of Set 12 | gornyye klyuchi
# Processing Record 29 of Set 12 | rosarito
# Processing Record 30 of Set 12 | kaeo
# Processing Record 31 of Set 12 | buchanan
# Processing Record 32 of Set 12 | warkworth
# Processing Record 33 of Set 12 | porosozero
# Processing Record 34 of Set 12 | geraldton
# Processing Record 35 of Set 12 | el alto
# Processing Record 36 of Set 12 | vyazma
# Processing Record 37 of Set 12 | wurzburg
# Processing Record 38 of Set 12 | ballina
# Processing Record 39 of Set 12 | medea
# Processing Record 40 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 41 of Set 12 | shimoda
# Processing Record 42 of Set 12 | praia da vitoria
# Processing Record 43 of Set 12 | taksimo
# Processing Record 44 of Set 12 | tonj
# Processing Record 45 of Set 12 | lavrentiya
# Processing Record 46 of Set 12 | thunder bay
# Processing Record 47 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 12 | husavik
# Processing Record 49 of Set 12 | shubarkuduk
# Processing Record 50 of Set 12 | vypolzovo
# Processing Record 1 of Set 13 | vao
# Processing Record 2 of Set 13 | oktyabrskoye
# Processing Record 3 of Set 13 | pangai
# Processing Record 4 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 13 | ibimirim
# Processing Record 6 of Set 13 | asosa
# Processing Record 7 of Set 13 | paamiut
# Processing Record 8 of Set 13 | poletayevo
# Processing Record 9 of Set 13 | yankton
# Processing Record 10 of Set 13 | vila franca do campo
# Processing Record 11 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 13 | barra
# Processing Record 13 of Set 13 | marovoay
# Processing Record 14 of Set 13 | kawalu
# Processing Record 15 of Set 13 | semirom
# Processing Record 16 of Set 13 | campo maior
# Processing Record 17 of Set 13 | san quintin
# Processing Record 18 of Set 13 | gondanglegi
# Processing Record 19 of Set 13 | todos santos
# Processing Record 20 of Set 13 | bouca
# Processing Record 21 of Set 13 | maceio
# Processing Record 22 of Set 13 | kloulklubed
# Processing Record 23 of Set 13 | balgazyn
# Processing Record 24 of Set 13 | aliwal north
# Processing Record 25 of Set 13 | baneh
# Processing Record 26 of Set 13 | sosnogorsk
# Processing Record 27 of Set 13 | kaniama
# Processing Record 28 of Set 13 | nijar
# Processing Record 29 of Set 13 | svetlyy
# Processing Record 30 of Set 13 | verkhnevilyuysk
# Processing Record 31 of Set 13 | chatsu
# City not found. Skipping...
# Processing Record 32 of Set 13 | necochea
# Processing Record 33 of Set 13 | we
# City not found. Skipping...
# Processing Record 34 of Set 13 | dattapur
# Processing Record 35 of Set 13 | mattru
# Processing Record 36 of Set 13 | teahupoo
# Processing Record 37 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 13 | ndele
# Processing Record 39 of Set 13 | tual
# Processing Record 40 of Set 13 | robertsport
# Processing Record 41 of Set 13 | mattawa
# Processing Record 42 of Set 13 | malatya
# Processing Record 43 of Set 13 | sangar
# Processing Record 44 of Set 13 | malabo
# Processing Record 45 of Set 13 | altonia
# City not found. Skipping...
# Processing Record 46 of Set 13 | tartagal
# Processing Record 47 of Set 13 | puerto escondido
# Processing Record 48 of Set 13 | whitehorse
# Processing Record 49 of Set 13 | panguipulli
# Processing Record 50 of Set 13 | karpathos
# Processing Record 1 of Set 14 | tessalit
# Processing Record 2 of Set 14 | harrisonburg
# Processing Record 3 of Set 14 | jilin
# Processing Record 4 of Set 14 | ilinge
# Processing Record 5 of Set 14 | fujin
# Processing Record 6 of Set 14 | santa rosalia
# Processing Record 7 of Set 14 | hirara
# Processing Record 8 of Set 14 | yar-sale
# Processing Record 9 of Set 14 | san angelo
# Processing Record 10 of Set 14 | rochester
# Processing Record 11 of Set 14 | mulege
# Processing Record 12 of Set 14 | najran
# Processing Record 13 of Set 14 | takoradi
# Processing Record 14 of Set 14 | ocala
# Processing Record 15 of Set 14 | montivilliers
# Processing Record 16 of Set 14 | puerto carreno
# Processing Record 17 of Set 14 | havoysund
# Processing Record 18 of Set 14 | maragogi
# Processing Record 19 of Set 14 | tawang
# Processing Record 20 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 14 | sakaiminato
# Processing Record 22 of Set 14 | buraydah
# Processing Record 23 of Set 14 | muros
# Processing Record 24 of Set 14 | san vicente
# Processing Record 25 of Set 14 | red bluff
# Processing Record 26 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 14 | dwarka
# Processing Record 28 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 29 of Set 14 | sawai madhopur
# Processing Record 30 of Set 14 | kochubey
# Processing Record 31 of Set 14 | mareeba
# Processing Record 32 of Set 14 | gorontalo
# Processing Record 33 of Set 14 | paciran
# Processing Record 34 of Set 14 | broome
# Processing Record 35 of Set 14 | uvinza
# Processing Record 36 of Set 14 | kuito
# Processing Record 37 of Set 14 | gualeguay
# Processing Record 38 of Set 14 | basse
# Processing Record 39 of Set 14 | gazanjyk
# Processing Record 40 of Set 14 | sioux lookout
# Processing Record 41 of Set 14 | riyadh
# Processing Record 42 of Set 14 | roald
# Processing Record 43 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 14 | biltine
# Processing Record 45 of Set 14 | urumqi
# Processing Record 46 of Set 14 | mombetsu
# Processing Record 47 of Set 14 | champerico
# Processing Record 48 of Set 14 | jutai
# Processing Record 49 of Set 14 | nara
# Processing Record 50 of Set 14 | smithers
# Processing Record 1 of Set 15 | merritt
# Processing Record 2 of Set 15 | san cristobal
# Processing Record 3 of Set 15 | gorin
# Processing Record 4 of Set 15 | simao
# Processing Record 5 of Set 15 | honningsvag
# Processing Record 6 of Set 15 | orlik
# Processing Record 7 of Set 15 | hamilton
# Processing Record 8 of Set 15 | kitgum
# Processing Record 9 of Set 15 | aripuana
# Processing Record 10 of Set 15 | puerto colombia
# Processing Record 11 of Set 15 | vila
# Processing Record 12 of Set 15 | port lincoln
# Processing Record 13 of Set 15 | willowmore
# Processing Record 14 of Set 15 | wajima
# Processing Record 15 of Set 15 | jining
# Processing Record 16 of Set 15 | svetlaya
# Processing Record 17 of Set 15 | emerald
# Processing Record 18 of Set 15 | oum hadjer
# Processing Record 19 of Set 15 | leninsk
# Processing Record 20 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 15 | porto belo
# Processing Record 22 of Set 15 | catalina
# Processing Record 23 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 15 | poya
# Processing Record 25 of Set 15 | deputatskiy
# Processing Record 26 of Set 15 | kiruna
# Processing Record 27 of Set 15 | dawson creek
# Processing Record 28 of Set 15 | shieli
# Processing Record 29 of Set 15 | raudeberg
# Processing Record 30 of Set 15 | benjamin constant
# Processing Record 31 of Set 15 | byron bay
# Processing Record 32 of Set 15 | aykhal
# Processing Record 33 of Set 15 | paredon
# Processing Record 34 of Set 15 | xingyi
# Processing Record 35 of Set 15 | horconcitos
# Processing Record 36 of Set 15 | bath
# Processing Record 37 of Set 15 | maracacume
# Processing Record 38 of Set 15 | port hawkesbury
# Processing Record 39 of Set 15 | lazurne
# Processing Record 40 of Set 15 | neiafu
# Processing Record 41 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 42 of Set 15 | severnyy-kospashskiy
# Processing Record 43 of Set 15 | wake forest
# Processing Record 44 of Set 15 | high level
# Processing Record 45 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 15 | shingu
# Processing Record 47 of Set 15 | zhigansk
# Processing Record 48 of Set 15 | neyshabur
# Processing Record 49 of Set 15 | valdivia
# Processing Record 50 of Set 15 | port hardy
# Processing Record 1 of Set 16 | manzhouli
# Processing Record 2 of Set 16 | one hundred mile house
# City not found. Skipping...
# Processing Record 3 of Set 16 | derzhavinsk
# Processing Record 4 of Set 16 | nabire
# Processing Record 5 of Set 16 | ihosy
# Processing Record 6 of Set 16 | bridlington
# Processing Record 7 of Set 16 | essex
# Processing Record 8 of Set 16 | bako
# Processing Record 9 of Set 16 | yagodnoye
# Processing Record 10 of Set 16 | darnah
# Processing Record 11 of Set 16 | koshurnikovo
# Processing Record 12 of Set 16 | luangwa
# Processing Record 13 of Set 16 | aguimes
# Processing Record 14 of Set 16 | clearwater
# Processing Record 15 of Set 16 | issenye
# Processing Record 16 of Set 16 | itamaraca
# Processing Record 17 of Set 16 | chapleau
# Processing Record 18 of Set 16 | roma
# Processing Record 19 of Set 16 | rassvet
# Processing Record 20 of Set 16 | el wasta
# City not found. Skipping...
# Processing Record 21 of Set 16 | bacolod
# Processing Record 22 of Set 16 | tovste
# Processing Record 23 of Set 16 | gilazi
# City not found. Skipping...
# Processing Record 24 of Set 16 | bad kreuznach
# Processing Record 25 of Set 16 | khagaria
# Processing Record 26 of Set 16 | preeceville
# Processing Record 27 of Set 16 | diveyevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 712

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ribeira Grande      PT  38.5167  -28.7000     63.00        82          75
# 1        Chipinge      ZW -20.1883   32.6236     65.86        69          39
# 2          Rorvik      NO  64.8621   11.2373     34.47        79         100
# 3        Hermanus      ZA -34.4187   19.2345     71.91        84          96
# 4         Rikitea      PF -23.1203 -134.9692     78.71        72          38
# 5        Hanzhong      CN  33.0728  107.0303     41.22        65          84
# 6        Kirakira      SB -10.4544  161.9205     77.54        88         100
# 7         Iqaluit      CA  63.7506  -68.5145    -24.07        62          20
# 8     Yellowknife      CA  62.4560 -114.3525    -19.71        80           0
# 9       Jamestown      US  42.0970  -79.2353     30.29        48         100
#
#    Wind Speed Current Description
# 0       19.57       broken clouds
# 1        5.10    scattered clouds
# 2       13.87     overcast clouds
# 3        6.53     overcast clouds
# 4       16.31    scattered clouds
# 5        0.67       broken clouds
# 6        5.19     overcast clouds
# 7        0.00          few clouds
# 8        4.61           clear sky
# 9       12.66     overcast clouds

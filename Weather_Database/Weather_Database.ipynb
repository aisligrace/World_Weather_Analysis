# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1f21a9c005f2d70a6053bd7288d45bd'

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | tvoroyri
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | geraldton
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | talnakh
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | roma
# Processing Record 10 of Set 1 | zhanaozen
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | vilhena
# Processing Record 14 of Set 1 | jishou
# Processing Record 15 of Set 1 | ginda
# Processing Record 16 of Set 1 | trincomalee
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | kouqian
# Processing Record 20 of Set 1 | alekseyevsk
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | superior
# Processing Record 24 of Set 1 | yeppoon
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | alugan
# Processing Record 28 of Set 1 | acajutla
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | dzhuryn
# Processing Record 31 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | leningradskiy
# Processing Record 38 of Set 1 | zabaykalsk
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | sitka
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | mangai
# Processing Record 47 of Set 1 | westport
# Processing Record 48 of Set 1 | margate
# Processing Record 49 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 1 | hofn
# Processing Record 1 of Set 2 | alofi
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | nicoya
# Processing Record 5 of Set 2 | igboho
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | kyabe
# Processing Record 9 of Set 2 | svetlyy
# Processing Record 10 of Set 2 | zhigansk
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | coihaique
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | demidov
# Processing Record 15 of Set 2 | insar
# Processing Record 16 of Set 2 | nishihara
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | preston
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | narsaq
# Processing Record 21 of Set 2 | waingapu
# Processing Record 22 of Set 2 | tonj
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | okahandja
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | wajima
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | bandarbeyla
# Processing Record 31 of Set 2 | san patricio
# Processing Record 32 of Set 2 | moissala
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | pisco
# Processing Record 35 of Set 2 | salalah
# Processing Record 36 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 2 | canico
# Processing Record 38 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | griffith
# Processing Record 41 of Set 2 | atar
# Processing Record 42 of Set 2 | berlevag
# Processing Record 43 of Set 2 | leh
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | mumbwa
# Processing Record 46 of Set 2 | manono
# Processing Record 47 of Set 2 | bintulu
# Processing Record 48 of Set 2 | port hardy
# Processing Record 49 of Set 2 | springbok
# Processing Record 50 of Set 2 | shimoda
# Processing Record 1 of Set 3 | kahului
# Processing Record 2 of Set 3 | christchurch
# Processing Record 3 of Set 3 | high level
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | sawakin
# Processing Record 6 of Set 3 | burnie
# Processing Record 7 of Set 3 | bara
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | egvekinot
# Processing Record 10 of Set 3 | merchtem
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | vanimo
# Processing Record 14 of Set 3 | roebourne
# Processing Record 15 of Set 3 | kamienna gora
# Processing Record 16 of Set 3 | jadu
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | paamiut
# Processing Record 19 of Set 3 | manta
# Processing Record 20 of Set 3 | garissa
# Processing Record 21 of Set 3 | mazulskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | abalak
# Processing Record 23 of Set 3 | takab
# Processing Record 24 of Set 3 | bairiki
# Processing Record 25 of Set 3 | verkhnyaya inta
# Processing Record 26 of Set 3 | husavik
# Processing Record 27 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 3 | fairbanks
# Processing Record 29 of Set 3 | ahuimanu
# Processing Record 30 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | vao
# Processing Record 33 of Set 3 | popova
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | tuensang
# Processing Record 36 of Set 3 | ponta delgada
# Processing Record 37 of Set 3 | pangnirtung
# Processing Record 38 of Set 3 | grenville
# Processing Record 39 of Set 3 | troitsko-pechorsk
# Processing Record 40 of Set 3 | tiarei
# Processing Record 41 of Set 3 | intibuca
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 3 | talara
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | jeremie
# Processing Record 47 of Set 3 | turukhansk
# Processing Record 48 of Set 3 | lao cai
# Processing Record 49 of Set 3 | phulji
# Processing Record 50 of Set 3 | saldanha
# Processing Record 1 of Set 4 | codrington
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | santo amaro da imperatriz
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | morant bay
# Processing Record 7 of Set 4 | stornoway
# Processing Record 8 of Set 4 | kerman
# Processing Record 9 of Set 4 | olinda
# Processing Record 10 of Set 4 | vestmannaeyjar
# Processing Record 11 of Set 4 | banda aceh
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | kaspiyskiy
# Processing Record 14 of Set 4 | champerico
# Processing Record 15 of Set 4 | arica
# Processing Record 16 of Set 4 | zhigalovo
# Processing Record 17 of Set 4 | kirra
# Processing Record 18 of Set 4 | cody
# Processing Record 19 of Set 4 | cabedelo
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 4 | wenling
# Processing Record 23 of Set 4 | tura
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | cockburn town
# Processing Record 26 of Set 4 | pacific grove
# Processing Record 27 of Set 4 | black river
# Processing Record 28 of Set 4 | taylorville
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | nanakuli
# Processing Record 31 of Set 4 | katobu
# Processing Record 32 of Set 4 | pitimbu
# Processing Record 33 of Set 4 | sept-iles
# Processing Record 34 of Set 4 | atasu
# Processing Record 35 of Set 4 | ahipara
# Processing Record 36 of Set 4 | komsomolskiy
# Processing Record 37 of Set 4 | qurayyat
# Processing Record 38 of Set 4 | youghal
# Processing Record 39 of Set 4 | tawnat
# City not found. Skipping...
# Processing Record 40 of Set 4 | kamenka
# Processing Record 41 of Set 4 | katsuura
# Processing Record 42 of Set 4 | mahon
# Processing Record 43 of Set 4 | comodoro rivadavia
# Processing Record 44 of Set 4 | dhidhdhoo
# Processing Record 45 of Set 4 | broome
# Processing Record 46 of Set 4 | anadyr
# Processing Record 47 of Set 4 | moerai
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | amazar
# Processing Record 50 of Set 4 | goderich
# Processing Record 1 of Set 5 | ostrovnoy
# Processing Record 2 of Set 5 | saint anthony
# Processing Record 3 of Set 5 | butaritari
# Processing Record 4 of Set 5 | yamada
# Processing Record 5 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 5 | mecca
# Processing Record 7 of Set 5 | namibe
# Processing Record 8 of Set 5 | gotsu
# Processing Record 9 of Set 5 | sitrah
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | port moresby
# Processing Record 12 of Set 5 | okha
# Processing Record 13 of Set 5 | novikovo
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | roald
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | arti
# Processing Record 18 of Set 5 | inhambane
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | asfi
# Processing Record 21 of Set 5 | eyl
# Processing Record 22 of Set 5 | barrow
# Processing Record 23 of Set 5 | kruisfontein
# Processing Record 24 of Set 5 | umea
# Processing Record 25 of Set 5 | manggar
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | ancud
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | saskylakh
# Processing Record 30 of Set 5 | esperance
# Processing Record 31 of Set 5 | guerrero negro
# Processing Record 32 of Set 5 | kununurra
# Processing Record 33 of Set 5 | mokhsogollokh
# Processing Record 34 of Set 5 | rio gallegos
# Processing Record 35 of Set 5 | savannah bight
# Processing Record 36 of Set 5 | tautira
# Processing Record 37 of Set 5 | kamennomostskiy
# Processing Record 38 of Set 5 | broken hill
# Processing Record 39 of Set 5 | susuman
# Processing Record 40 of Set 5 | kuytun
# Processing Record 41 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 42 of Set 5 | nouakchott
# Processing Record 43 of Set 5 | chipinge
# Processing Record 44 of Set 5 | baraboo
# Processing Record 45 of Set 5 | beloha
# Processing Record 46 of Set 5 | nikolskoye
# Processing Record 47 of Set 5 | homer
# Processing Record 48 of Set 5 | saraza
# Processing Record 49 of Set 5 | walvis bay
# Processing Record 50 of Set 5 | imeni poliny osipenko
# Processing Record 1 of Set 6 | san jose de ocoa
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | bow island
# Processing Record 4 of Set 6 | sioux lookout
# Processing Record 5 of Set 6 | mount gambier
# Processing Record 6 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 6 | moron
# Processing Record 8 of Set 6 | ternate
# Processing Record 9 of Set 6 | vostok
# Processing Record 10 of Set 6 | mount vernon
# Processing Record 11 of Set 6 | padang
# Processing Record 12 of Set 6 | valdivia
# Processing Record 13 of Set 6 | gondanglegi
# Processing Record 14 of Set 6 | nikki
# Processing Record 15 of Set 6 | pevek
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | sorland
# Processing Record 18 of Set 6 | redmond
# Processing Record 19 of Set 6 | ketchikan
# Processing Record 20 of Set 6 | mangrol
# Processing Record 21 of Set 6 | half moon bay
# Processing Record 22 of Set 6 | severo-kurilsk
# Processing Record 23 of Set 6 | armidale
# Processing Record 24 of Set 6 | sawtell
# Processing Record 25 of Set 6 | pochutla
# Processing Record 26 of Set 6 | henties bay
# Processing Record 27 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 6 | elat
# Processing Record 29 of Set 6 | airai
# Processing Record 30 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 6 | palmer
# Processing Record 32 of Set 6 | kenai
# Processing Record 33 of Set 6 | kalabo
# Processing Record 34 of Set 6 | willowmore
# Processing Record 35 of Set 6 | upernavik
# Processing Record 36 of Set 6 | karratha
# Processing Record 37 of Set 6 | kazan
# Processing Record 38 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 6 | togur
# Processing Record 40 of Set 6 | ugoofaaru
# Processing Record 41 of Set 6 | sabya
# Processing Record 42 of Set 6 | chokurdakh
# Processing Record 43 of Set 6 | manturovo
# Processing Record 44 of Set 6 | am timan
# Processing Record 45 of Set 6 | sibolga
# Processing Record 46 of Set 6 | mareeba
# Processing Record 47 of Set 6 | bambari
# Processing Record 48 of Set 6 | ulladulla
# Processing Record 49 of Set 6 | vershino-darasunskiy
# Processing Record 50 of Set 6 | codo
# Processing Record 1 of Set 7 | katherine
# Processing Record 2 of Set 7 | almaznyy
# Processing Record 3 of Set 7 | san cristobal
# Processing Record 4 of Set 7 | ambilobe
# Processing Record 5 of Set 7 | gawler
# Processing Record 6 of Set 7 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 7 of Set 7 | darhan
# Processing Record 8 of Set 7 | san marcos
# Processing Record 9 of Set 7 | saint-joseph
# Processing Record 10 of Set 7 | dogondoutchi
# Processing Record 11 of Set 7 | cherdyn
# Processing Record 12 of Set 7 | otavi
# Processing Record 13 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 14 of Set 7 | kaeo
# Processing Record 15 of Set 7 | sao filipe
# Processing Record 16 of Set 7 | along
# Processing Record 17 of Set 7 | voh
# Processing Record 18 of Set 7 | caravelas
# Processing Record 19 of Set 7 | salta
# Processing Record 20 of Set 7 | truth or consequences
# Processing Record 21 of Set 7 | saint-augustin
# Processing Record 22 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 7 | provideniya
# Processing Record 24 of Set 7 | belmonte
# Processing Record 25 of Set 7 | faya
# Processing Record 26 of Set 7 | la ronge
# Processing Record 27 of Set 7 | yumen
# Processing Record 28 of Set 7 | havre-saint-pierre
# Processing Record 29 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 30 of Set 7 | kirakira
# Processing Record 31 of Set 7 | ponta do sol
# Processing Record 32 of Set 7 | itupiranga
# Processing Record 33 of Set 7 | krasnaya gora
# Processing Record 34 of Set 7 | sola
# Processing Record 35 of Set 7 | plast
# Processing Record 36 of Set 7 | jalpa
# Processing Record 37 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 7 | bangassou
# Processing Record 39 of Set 7 | dauriya
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | poya
# Processing Record 42 of Set 7 | minna
# Processing Record 43 of Set 7 | kodiak
# Processing Record 44 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 7 | krasnoselkup
# Processing Record 46 of Set 7 | tarko-sale
# Processing Record 47 of Set 7 | kyabram
# Processing Record 48 of Set 7 | vega de alatorre
# Processing Record 49 of Set 7 | hami
# Processing Record 50 of Set 7 | manali
# Processing Record 1 of Set 8 | krivopolyanye
# City not found. Skipping...
# Processing Record 2 of Set 8 | bay roberts
# Processing Record 3 of Set 8 | torbay
# Processing Record 4 of Set 8 | najran
# Processing Record 5 of Set 8 | manokwari
# Processing Record 6 of Set 8 | quatre cocos
# Processing Record 7 of Set 8 | muyinga
# Processing Record 8 of Set 8 | arlit
# Processing Record 9 of Set 8 | cabra
# Processing Record 10 of Set 8 | benguela
# Processing Record 11 of Set 8 | cidreira
# Processing Record 12 of Set 8 | tome-acu
# City not found. Skipping...
# Processing Record 13 of Set 8 | kuli
# Processing Record 14 of Set 8 | oran
# Processing Record 15 of Set 8 | omsukchan
# Processing Record 16 of Set 8 | kabarnet
# Processing Record 17 of Set 8 | seoul
# Processing Record 18 of Set 8 | aloleng
# Processing Record 19 of Set 8 | kulhudhuffushi
# Processing Record 20 of Set 8 | neuquen
# Processing Record 21 of Set 8 | piedras negras
# Processing Record 22 of Set 8 | mangaratiba
# Processing Record 23 of Set 8 | devils lake
# Processing Record 24 of Set 8 | mkushi
# Processing Record 25 of Set 8 | izhma
# Processing Record 26 of Set 8 | chumikan
# Processing Record 27 of Set 8 | ayan
# Processing Record 28 of Set 8 | vallenar
# Processing Record 29 of Set 8 | norman wells
# Processing Record 30 of Set 8 | kavaratti
# Processing Record 31 of Set 8 | chingola
# Processing Record 32 of Set 8 | young
# Processing Record 33 of Set 8 | lasa
# Processing Record 34 of Set 8 | luderitz
# Processing Record 35 of Set 8 | wakkanai
# Processing Record 36 of Set 8 | klaksvik
# Processing Record 37 of Set 8 | kralendijk
# Processing Record 38 of Set 8 | olafsvik
# Processing Record 39 of Set 8 | ternuvate
# Processing Record 40 of Set 8 | yulara
# Processing Record 41 of Set 8 | port elizabeth
# Processing Record 42 of Set 8 | torres
# Processing Record 43 of Set 8 | floresta
# Processing Record 44 of Set 8 | sur
# Processing Record 45 of Set 8 | yenagoa
# Processing Record 46 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 8 | byron bay
# Processing Record 48 of Set 8 | shubarshi
# Processing Record 49 of Set 8 | iqaluit
# Processing Record 50 of Set 8 | peque
# Processing Record 1 of Set 9 | mogocha
# Processing Record 2 of Set 9 | nanortalik
# Processing Record 3 of Set 9 | sisimiut
# Processing Record 4 of Set 9 | puerto carreno
# Processing Record 5 of Set 9 | ivancsa
# Processing Record 6 of Set 9 | naze
# Processing Record 7 of Set 9 | northam
# Processing Record 8 of Set 9 | malindi
# Processing Record 9 of Set 9 | borshchiv
# Processing Record 10 of Set 9 | phenix city
# Processing Record 11 of Set 9 | charlestown
# Processing Record 12 of Set 9 | ranong
# Processing Record 13 of Set 9 | sergeyevka
# Processing Record 14 of Set 9 | puqi
# Processing Record 15 of Set 9 | dingle
# Processing Record 16 of Set 9 | marawi
# Processing Record 17 of Set 9 | nalut
# Processing Record 18 of Set 9 | atherton
# Processing Record 19 of Set 9 | blythe
# Processing Record 20 of Set 9 | flin flon
# Processing Record 21 of Set 9 | lagoa
# Processing Record 22 of Set 9 | yarada
# Processing Record 23 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 9 | solaro
# Processing Record 25 of Set 9 | nome
# Processing Record 26 of Set 9 | yalta
# Processing Record 27 of Set 9 | larsnes
# Processing Record 28 of Set 9 | san quintin
# Processing Record 29 of Set 9 | ferme-neuve
# Processing Record 30 of Set 9 | imbituba
# Processing Record 31 of Set 9 | mulhouse
# Processing Record 32 of Set 9 | bernalillo
# Processing Record 33 of Set 9 | chuy
# Processing Record 34 of Set 9 | santiago
# Processing Record 35 of Set 9 | guanare
# Processing Record 36 of Set 9 | maragogi
# Processing Record 37 of Set 9 | gillingham
# Processing Record 38 of Set 9 | nong chik
# Processing Record 39 of Set 9 | kashan
# Processing Record 40 of Set 9 | opuwo
# Processing Record 41 of Set 9 | guilin
# Processing Record 42 of Set 9 | vila franca do campo
# Processing Record 43 of Set 9 | necochea
# Processing Record 44 of Set 9 | hervey bay
# Processing Record 45 of Set 9 | kindersley
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | mikun
# Processing Record 48 of Set 9 | bathsheba
# Processing Record 49 of Set 9 | inirida
# Processing Record 50 of Set 9 | krasnyy
# Processing Record 1 of Set 10 | leiyang
# Processing Record 2 of Set 10 | kilakarai
# Processing Record 3 of Set 10 | alenquer
# Processing Record 4 of Set 10 | tommot
# Processing Record 5 of Set 10 | touros
# Processing Record 6 of Set 10 | namatanai
# Processing Record 7 of Set 10 | duldurga
# Processing Record 8 of Set 10 | bloemfontein
# Processing Record 9 of Set 10 | adrar
# Processing Record 10 of Set 10 | chippewa falls
# Processing Record 11 of Set 10 | douglas
# Processing Record 12 of Set 10 | kushiro
# Processing Record 13 of Set 10 | puerto escondido
# Processing Record 14 of Set 10 | kyshtovka
# Processing Record 15 of Set 10 | deputatskiy
# Processing Record 16 of Set 10 | khani
# Processing Record 17 of Set 10 | harrisonburg
# Processing Record 18 of Set 10 | yazd
# Processing Record 19 of Set 10 | krasnokamensk
# Processing Record 20 of Set 10 | mincivan
# Processing Record 21 of Set 10 | lorengau
# Processing Record 22 of Set 10 | flinders
# Processing Record 23 of Set 10 | bone
# Processing Record 24 of Set 10 | phuket
# Processing Record 25 of Set 10 | sinnamary
# Processing Record 26 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 10 | kalga
# Processing Record 28 of Set 10 | roquetas de mar
# Processing Record 29 of Set 10 | selfoss
# Processing Record 30 of Set 10 | keti bandar
# Processing Record 31 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 10 | nizhnevartovsk
# Processing Record 33 of Set 10 | gat
# Processing Record 34 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 36 of Set 10 | montrose
# Processing Record 37 of Set 10 | dumbravita
# Processing Record 38 of Set 10 | sabinas hidalgo
# Processing Record 39 of Set 10 | porterville
# Processing Record 40 of Set 10 | mitu
# Processing Record 41 of Set 10 | amga
# Processing Record 42 of Set 10 | shasta lake
# Processing Record 43 of Set 10 | we
# City not found. Skipping...
# Processing Record 44 of Set 10 | emba
# Processing Record 45 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | jablah
# Processing Record 47 of Set 10 | mityana
# Processing Record 48 of Set 10 | general nakar
# Processing Record 49 of Set 10 | honiara
# Processing Record 50 of Set 10 | nioro
# Processing Record 1 of Set 11 | jalu
# Processing Record 2 of Set 11 | lagunas
# Processing Record 3 of Set 11 | mocuba
# Processing Record 4 of Set 11 | bukid
# Processing Record 5 of Set 11 | richards bay
# Processing Record 6 of Set 11 | tulsipur
# Processing Record 7 of Set 11 | poso
# Processing Record 8 of Set 11 | yinchuan
# Processing Record 9 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 11 | kautokeino
# Processing Record 11 of Set 11 | mendoza
# Processing Record 12 of Set 11 | esna
# Processing Record 13 of Set 11 | alexandria
# Processing Record 14 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 15 of Set 11 | jinchang
# Processing Record 16 of Set 11 | college
# Processing Record 17 of Set 11 | laguna
# Processing Record 18 of Set 11 | barsi
# Processing Record 19 of Set 11 | vila
# Processing Record 20 of Set 11 | leavenworth
# Processing Record 21 of Set 11 | omboue
# Processing Record 22 of Set 11 | camana
# Processing Record 23 of Set 11 | tabuk
# Processing Record 24 of Set 11 | dzaoudzi
# Processing Record 25 of Set 11 | veraval
# Processing Record 26 of Set 11 | rio grande
# Processing Record 27 of Set 11 | baruun-urt
# Processing Record 28 of Set 11 | port hedland
# Processing Record 29 of Set 11 | batsfjord
# Processing Record 30 of Set 11 | marabba
# Processing Record 31 of Set 11 | la primavera
# Processing Record 32 of Set 11 | hovd
# Processing Record 33 of Set 11 | mehamn
# Processing Record 34 of Set 11 | oistins
# Processing Record 35 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 36 of Set 11 | denpasar
# Processing Record 37 of Set 11 | ryzdvyanyy
# Processing Record 38 of Set 11 | barreirinhas
# Processing Record 39 of Set 11 | faanui
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | kismayo
# Processing Record 42 of Set 11 | gunjur
# Processing Record 43 of Set 11 | maningrida
# Processing Record 44 of Set 11 | maciel
# Processing Record 45 of Set 11 | birjand
# Processing Record 46 of Set 11 | santa cruz
# Processing Record 47 of Set 11 | kupang
# Processing Record 48 of Set 11 | langsa
# Processing Record 49 of Set 11 | belaya glina
# Processing Record 50 of Set 11 | vieux-habitants
# Processing Record 1 of Set 12 | saint-francois
# Processing Record 2 of Set 12 | nizwa
# Processing Record 3 of Set 12 | gharb
# City not found. Skipping...
# Processing Record 4 of Set 12 | buala
# Processing Record 5 of Set 12 | inuvik
# Processing Record 6 of Set 12 | kavieng
# Processing Record 7 of Set 12 | djambala
# Processing Record 8 of Set 12 | karlskoga
# Processing Record 9 of Set 12 | okhotsk
# Processing Record 10 of Set 12 | mahajanga
# Processing Record 11 of Set 12 | tilichiki
# Processing Record 12 of Set 12 | dali
# Processing Record 13 of Set 12 | ambatondrazaka
# Processing Record 14 of Set 12 | meulaboh
# Processing Record 15 of Set 12 | bilibino
# Processing Record 16 of Set 12 | zhumadian
# Processing Record 17 of Set 12 | mokolo
# Processing Record 18 of Set 12 | summerside
# Processing Record 19 of Set 12 | bartica
# Processing Record 20 of Set 12 | peoria
# Processing Record 21 of Set 12 | puerto baquerizo moreno
# Processing Record 22 of Set 12 | khorixas
# Processing Record 23 of Set 12 | bukama
# Processing Record 24 of Set 12 | allende
# Processing Record 25 of Set 12 | fare
# Processing Record 26 of Set 12 | matagami
# Processing Record 27 of Set 12 | galle
# Processing Record 28 of Set 12 | puerto del rosario
# Processing Record 29 of Set 12 | gorom-gorom
# Processing Record 30 of Set 12 | enid
# Processing Record 31 of Set 12 | sechura
# Processing Record 32 of Set 12 | rush
# Processing Record 33 of Set 12 | ko samui
# Processing Record 34 of Set 12 | ligayan
# Processing Record 35 of Set 12 | pishin
# Processing Record 36 of Set 12 | xining
# Processing Record 37 of Set 12 | locri
# Processing Record 38 of Set 12 | smolenka
# Processing Record 39 of Set 12 | srednekolymsk
# Processing Record 40 of Set 12 | jackson
# Processing Record 41 of Set 12 | mandalgovi
# Processing Record 42 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 12 | hope
# Processing Record 44 of Set 12 | urumqi
# Processing Record 45 of Set 12 | rundu
# Processing Record 46 of Set 12 | ypsonas
# Processing Record 47 of Set 12 | fougeres
# Processing Record 48 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 49 of Set 12 | baykit
# Processing Record 50 of Set 12 | finnsnes
# Processing Record 1 of Set 13 | nizhniy tagil
# Processing Record 2 of Set 13 | vidim
# Processing Record 3 of Set 13 | awjilah
# Processing Record 4 of Set 13 | saiha
# Processing Record 5 of Set 13 | belaya gora
# Processing Record 6 of Set 13 | caltagirone
# Processing Record 7 of Set 13 | bubaque
# Processing Record 8 of Set 13 | kirkenes
# Processing Record 9 of Set 13 | antofagasta
# Processing Record 10 of Set 13 | sorong
# Processing Record 11 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 13 | lazurne
# Processing Record 13 of Set 13 | usinsk
# Processing Record 14 of Set 13 | bagotville
# Processing Record 15 of Set 13 | briancon
# Processing Record 16 of Set 13 | gannan
# Processing Record 17 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 13 | lingyuan
# Processing Record 19 of Set 13 | avera
# Processing Record 20 of Set 13 | ipoh
# Processing Record 21 of Set 13 | lata
# Processing Record 22 of Set 13 | grindavik
# Processing Record 23 of Set 13 | mochalishche
# Processing Record 24 of Set 13 | port pirie
# Processing Record 25 of Set 13 | malanje
# Processing Record 26 of Set 13 | pizarro
# Processing Record 27 of Set 13 | santa marta
# Processing Record 28 of Set 13 | makarov
# Processing Record 29 of Set 13 | nemuro
# Processing Record 30 of Set 13 | payson
# Processing Record 31 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 13 | jumla
# Processing Record 33 of Set 13 | tiznit
# Processing Record 34 of Set 13 | murud
# Processing Record 35 of Set 13 | mackenzie
# Processing Record 36 of Set 13 | twentynine palms
# Processing Record 37 of Set 13 | paysandu
# Processing Record 38 of Set 13 | iralaya
# Processing Record 39 of Set 13 | sabang
# Processing Record 40 of Set 13 | thaton
# Processing Record 41 of Set 13 | alibag
# Processing Record 42 of Set 13 | beni
# Processing Record 43 of Set 13 | blackwater
# Processing Record 44 of Set 13 | bridlington
# Processing Record 45 of Set 13 | tessalit
# Processing Record 46 of Set 13 | ballangen
# Processing Record 47 of Set 13 | lincoln
# Processing Record 48 of Set 13 | igarka
# Processing Record 49 of Set 13 | raga
# Processing Record 50 of Set 13 | laurel
# Processing Record 1 of Set 14 | dubbo
# Processing Record 2 of Set 14 | senj
# Processing Record 3 of Set 14 | bafq
# Processing Record 4 of Set 14 | taltal
# Processing Record 5 of Set 14 | pilar
# Processing Record 6 of Set 14 | kashi
# Processing Record 7 of Set 14 | pyay
# Processing Record 8 of Set 14 | saurimo
# Processing Record 9 of Set 14 | dunedin
# Processing Record 10 of Set 14 | izumo
# Processing Record 11 of Set 14 | sistranda
# Processing Record 12 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 13 of Set 14 | jacareacanga
# Processing Record 14 of Set 14 | karmana
# City not found. Skipping...
# Processing Record 15 of Set 14 | uyskoye
# Processing Record 16 of Set 14 | suratgarh
# Processing Record 17 of Set 14 | kankon
# Processing Record 18 of Set 14 | mattru
# Processing Record 19 of Set 14 | yabrud
# Processing Record 20 of Set 14 | sakakah
# Processing Record 21 of Set 14 | uttarkashi
# Processing Record 22 of Set 14 | marsh harbour
# Processing Record 23 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 24 of Set 14 | ginir
# Processing Record 25 of Set 14 | kem
# Processing Record 26 of Set 14 | naples
# Processing Record 27 of Set 14 | rock sound
# Processing Record 28 of Set 14 | nyurba
# Processing Record 29 of Set 14 | severobaykalsk
# Processing Record 30 of Set 14 | kemijarvi
# Processing Record 31 of Set 14 | cumberland
# Processing Record 32 of Set 14 | santa cruz del norte
# Processing Record 33 of Set 14 | wanning
# Processing Record 34 of Set 14 | san andres
# Processing Record 35 of Set 14 | llandrindod wells
# Processing Record 36 of Set 14 | mishan
# Processing Record 37 of Set 14 | nanzhang
# Processing Record 38 of Set 14 | mutoko
# Processing Record 39 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 40 of Set 14 | bata
# Processing Record 41 of Set 14 | pagudpud
# Processing Record 42 of Set 14 | mao
# Processing Record 43 of Set 14 | velikiy ustyug
# Processing Record 44 of Set 14 | muros
# Processing Record 45 of Set 14 | chimbote
# Processing Record 46 of Set 14 | kargasok
# Processing Record 47 of Set 14 | inverness
# Processing Record 48 of Set 14 | kysyl-syr
# Processing Record 49 of Set 14 | erenhot
# Processing Record 50 of Set 14 | jodhpur
# Processing Record 1 of Set 15 | pokhara
# Processing Record 2 of Set 15 | malkara
# Processing Record 3 of Set 15 | isangel
# Processing Record 4 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 5 of Set 15 | songjianghe
# Processing Record 6 of Set 15 | judenburg
# Processing Record 7 of Set 15 | sedam
# Processing Record 8 of Set 15 | gamba
# Processing Record 9 of Set 15 | kalmar
# Processing Record 10 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 15 | samarai
# Processing Record 12 of Set 15 | formosa
# Processing Record 13 of Set 15 | krasnaya poyma
# Processing Record 14 of Set 15 | batagay
# Processing Record 15 of Set 15 | beringovskiy
# Processing Record 16 of Set 15 | tual
# Processing Record 17 of Set 15 | joutseno
# Processing Record 18 of Set 15 | huittinen
# Processing Record 19 of Set 15 | ilo
# Processing Record 20 of Set 15 | shatsk
# Processing Record 21 of Set 15 | rybnaya sloboda
# Processing Record 22 of Set 15 | kurilsk
# Processing Record 23 of Set 15 | mount isa
# Processing Record 24 of Set 15 | itaueira
# Processing Record 25 of Set 15 | lengshuijiang
# Processing Record 26 of Set 15 | serebryanyy bor
# Processing Record 27 of Set 15 | rocha
# Processing Record 28 of Set 15 | aklavik
# Processing Record 29 of Set 15 | lakatoro
# Processing Record 30 of Set 15 | mount pleasant
# Processing Record 31 of Set 15 | ozinki
# Processing Record 32 of Set 15 | yushu
# Processing Record 33 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 34 of Set 15 | russell
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     78.71        72          38
# 1        Tvoroyri      FO  61.5556   -6.8111     40.39        88         100
# 2     East London      ZA -33.0153   27.9116     78.73        84           0
# 3       Geraldton      AU -28.7667  114.6000     70.21        78           5
# 4          Albany      US  42.6001  -73.9662     52.09        44          99
# 5         Talnakh      RU  69.4865   88.3972     -9.33        79          37
# 6            Hilo      US  19.7297 -155.0900     68.11        82          20
# 7  Saint-Philippe      RE -21.3585   55.7679     78.39        79          16
# 8            Roma      US  43.2128  -75.4557     41.38        64         100
# 9       Zhanaozen      KZ  43.3000   52.8000     39.61        82          86
#
#    Wind Speed Current Description
# 0       16.31    scattered clouds
# 1       17.52     overcast clouds
# 2       16.06           clear sky
# 3       10.36           clear sky
# 4        1.99     overcast clouds
# 5        9.84    scattered clouds
# 6        5.99          few clouds
# 7        6.82          few clouds
# 8       17.00     overcast clouds
# 9        7.99     overcast clouds

# %%
# Convert and export df as csv
city_data_df.to_csv('weather_database.csv')
